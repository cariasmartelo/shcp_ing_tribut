# %% [markdown]
# # Pipeline Multivariate Descriptive
# Análisis de
# - IGAE
# - TC
# - Tasa Int
# - Otros

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from pylab import rcParams
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.tsa.stattools import acf, pacf, adfuller, arma_order_select_ic
from sklearn.model_selection import ParameterGrid
import itertools
import warnings
import seaborn as sns



#Own packages
import download
import descriptive
import models_multivariate

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Importamos datos

# %%
# Importamos csv con ingresos brutos
ingresos_totales = download.load_ingresos_fiscales('../inputs/ingresos_tributarios_desglosados_updated.xlsx')

# Pib real
pib_r_df = download.load_pib_r()
pib_r_df_sa = download.load_pib_r(sa=True)
# Igaes
igae = download.load_inegi_indic('igae')
igae_prim = download.load_inegi_indic('igae_prim')
igae_secun = download.load_inegi_indic('igae_secun')
igae_terc = download.load_inegi_indic('igae_terc')

# Imai
imai = download.load_inegi_indic('imai')
imai_mineria = download.load_inegi_indic('imai_mineria')
imai_egergia_gas_agua_gas = download.load_inegi_indic('imai_egergia_gas_agua_gas')
imai_construccion = download.load_inegi_indic('imai_construccion')
imai_manufacturas = download.load_inegi_indic('imai_manufacturas')

# Otros indicadores de INEGI
confianza_consumidor = download.load_inegi_indic('confianza_consumidor')
indic_mens_consumo = download.load_inegi_indic('indic_mens_consumo')
indic_adelant = download.load_inegi_indic('indic_adelant')

# Ocupación
pea = download.load_inegi_indic('pea')
pobl_ocupada = download.load_inegi_indic('pobl_ocupada')
asegurados_imss = download.load_inegi_indic('asegurados_imss')

# Tipo de cambio
tc_mensual = download.load_banxico('tc_mensual')
tc_real = download.load_banxico('indice_tc_real')

# Tasas de interés
tasa_cetes_91_mensual = download.load_banxico('tasa_cetes_91_mensual')
tbill_3meses_mensual = download.load_fed('tbill_3meses_mensual')

# Precios
cons_price_index_us = download.load_fed('cons_price_index_us')
inpc = download.load_inpc()

# Indicadores US
ind_prod_ind_us = download.load_fed('ind_prod_ind_us')

#PIB real US
pib_r_us = download.load_fed('pibr_us_2012', monthly = True)

# %% [markdown]
# # Creamos DF conjunto

# %%
df_netos = pd.concat([ingresos_totales, igae, imai, pib_r_df, igae_prim, igae_secun, igae_terc,
                      confianza_consumidor, indic_mens_consumo, indic_adelant, pea, pobl_ocupada,
                      asegurados_imss, tc_mensual, tc_real, tasa_cetes_91_mensual,
                      tbill_3meses_mensual, cons_price_index_us, ind_prod_ind_us, pib_r_us, inpc], axis=1)

# %% [markdown]
# # Filtramos datos para solo tener después de 2005

# %%
dates_to_use = pd.date_range('2004-01-01', '2019-06-01', freq='MS')
df_netos = df_netos.loc[dates_to_use]

# %% [markdown]
# # Diccionario de columnas

# %%
df_netos.columns
# Out:
# Index(['ingresos_sector_publico_neto_(mdp)', 'ieps_neto_(mdp)',
#        'ieps_sin_gas_neto_(mdp)', 'ing_gob_fed_neto_(mdp)',
#        'ing_trib_neto_(mdp)', 'isr_neto_(mdp)', 'iva_neto_(mdp)',
#        'importaciones_neto_(mdp)', 'ing_no_trib_neto_(mdp)',
#        'ieps_hidrocarburos_neto_(mdp)',
#        ...
#        'pobl_ocupada', 'asegurados_imss', 'tc_mensual', 'indice_tc_real',
#        'tasa_cetes_91_mensual', 'tbill_3meses_mensual', 'cons_price_index_us',
#        'ind_prod_ind_us', 'pibr_us_2012', 'inpc'],
#       dtype='object', length=142)

# %%
ingresos_tributarios_nominal = (['ingresos_sector_publico_neto_(mdp)', 'iva_neto_(mdp)', 'ieps_neto_(mdp)',
                                 'ieps_gasolina_neto_(mdp)', 'ing_no_trib_neto_(mdp)',
                                 'ing_gob_fed_neto_(mdp)', 'ing_trib_neto_(mdp)',
                                 'isr_neto_(mdp)', 'ing_trib_sin_gasol_neto_(mdp)',
                                 'ieps_sin_gas_neto_(mdp)'])
ingresos_tributarios_real = (['ingresos_sector_publico_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ieps_neto_(mdp)_r',
                              'ieps_gasolina_neto_(mdp)_r', 'ing_no_trib_neto_(mdp)_r',
                              'ing_gob_fed_neto_(mdp)_r', 'ing_trib_neto_(mdp)_r',
                              'isr_neto_(mdp)_r', 'ing_trib_sin_gasol_neto_(mdp)_r',
                              'ieps_sin_gas_neto_(mdp)_r'])
impuestos_netos = ['ing_trib_sin_gasol_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'isr_neto_(mdp)_r',\
                   'ieps_sin_gas_neto_(mdp)_r']

impuestos_brutos = ['ing_trib_bruto_(mdp)_r', 'iva_bruto_(mdp)_r', 'isr_bruto_(mdp)_r',\
                    'ieps_bruto_(mdp)_r']


igaes = ['igae', 'igae_prim', 'igae_secun', 'igae_terc']
imai = ['imai']
ocupacion = ['pea', 'pobl_ocupada']
asegurados = ['asegurados_imss']
indicadores_reales = ['confianza_consumidor', 'indic_mens_consumo', 'indic_adelant']
financieros = ['inpc', 'tc_mensual', 'indice_tc_real', 'cons_price_index_us', 'tasa_cetes_91_mensual',\
               'tbill_3meses_mensual']
pibs = ['pibr_2019', 'pibr_us_2012']
indice_produccion_us = ['ind_prod_ind_us']               

# Otros grupos no excluyentes, utiles
tasas_3_meses = ['tasa_cetes_91_mensual', 'tbill_3meses_mensual']
precios = ['inpc', 'cons_price_index_us']
indices_produccion = ['igae', 'ind_prod_ind_us']

# Columnas que se agregan usando promedio
agg_by_mean = igaes + ocupacion + indicadores_reales + financieros + pibs + indice_produccion_us + imai
# Columnas que se agregan con suma
agg_by_sum = ingresos_tributarios_nominal + ingresos_tributarios_real + impuestos_brutos
# Columnas que se agregan con el ultimo dato (Stock)
agg_by_last = asegurados

# %% [markdown]
# # Análisis variables
# Vamos a analizar el comportamiento de las variables.

# %%
descriptive.plot_series(df = df_netos, 
                        cols = tasas_3_meses,
                        legend= ['CETES 91',
                                 'T-Bills 3 meses'],
                        title = 'Tasas de interés soberana de México y Estados Unidos',
                        subtitle = 'Promedio mensual (%)',
                        ticks='yearly', 
                        hline=0,
                        figsize = (10, 6),
                       dpi=100)

# %% [markdown]
# ## Análisis anual

# %%
'inpc' in df_netos.columns
# Out:
# True

# %%
agg_by_mean_y = df_netos[agg_by_mean].resample('YS').mean()
agg_by_sum_y = df_netos[agg_by_sum].resample('YS').sum()
my_resample = lambda x: x.sort_index().tail(1)
agg_by_last_y = df_netos[agg_by_last].groupby(pd.TimeGrouper(freq='YS'), group_keys=False).apply(my_resample)
agg_by_last_y.index = pd.date_range('2004-01-01', '2019-01-01', freq='YS')

# Creamos base anual conjunta
yearly = pd.concat([agg_by_mean_y, agg_by_sum_y, agg_by_last_y], axis=1)

# Eliminamos ultimo año por recaudacion incompleta
yearly = yearly.iloc[:-1]

# %%
yearly.columns
# Out:
# Index(['igae', 'igae_prim', 'igae_secun', 'igae_terc', 'pea', 'pobl_ocupada',
#        'confianza_consumidor', 'indic_mens_consumo', 'indic_adelant', 'inpc',
#        'tc_mensual', 'indice_tc_real', 'cons_price_index_us',
#        'tasa_cetes_91_mensual', 'tbill_3meses_mensual', 'pibr_2019',
#        'pibr_us_2012', 'ind_prod_ind_us', 'imai',
#        'ingresos_sector_publico_neto_(mdp)', 'iva_neto_(mdp)',
#        'ieps_neto_(mdp)', 'ieps_gasolina_neto_(mdp)', 'ing_no_trib_neto_(mdp)',
#        'ing_gob_fed_neto_(mdp)', 'ing_trib_neto_(mdp)', 'isr_neto_(mdp)',
#        'ing_trib_sin_gasol_neto_(mdp)', 'ieps_sin_gas_neto_(mdp)',
#        'ingresos_sector_publico_neto_(mdp)_r', 'iva_neto_(mdp)_r',
#        'ieps_neto_(mdp)_r', 'ieps_gasolina_neto_(mdp)_r',
#        'ing_no_trib_neto_(mdp)_r', 'ing_gob_fed_neto_(mdp)_r',
#        'ing_trib_neto_(mdp)_r', 'isr_neto_(mdp)_r',
#        'ing_trib_sin_gasol_neto_(mdp)_r', 'ieps_sin_gas_neto_(mdp)_r',
#        'ing_trib_bruto_(mdp)_r', 'iva_bruto_(mdp)_r', 'isr_bruto_(mdp)_r',
#        'ieps_bruto_(mdp)_r', 'asegurados_imss'],
#       dtype='object')

# %%
descriptive.plot_series(df = yearly, 
                        cols = impuestos_netos,
                        legend= ['Ingresos tributarios',
                                 'IVA',
                                 'ISR',
                                 'IEPS sin gaolina'],
                        title = 'Ingresos tributarios netos sin gasolina del Gobierno Federal',
                        subtitle = '(MDP)',
                        ticks='yearly', 
                        figsize = (10, 6))

# %%
descriptive.plot_series(df = (yearly[pibs].pct_change()) * 100,
                        legend= ['Mexico',
                                 'Estados Unidos'],
                        title = 'Crecimiento anual del Producto Interno Bruto de México y Estados Unidos',
                        subtitle = '(%)',
                        ticks='yearly',
                        hline=0,
                        figsize = (10, 6),
                        dpi=100,
                        save_to='../figures/crecimiento_usa_mex.png')

# %% [markdown]
# ### Indicador 2005 = 100

# %%
# Creamos indice base anual de indices
yearly_index = yearly.apply(lambda x: (x / x.iloc[0]) * 100)

# %%
yearly_index[['imai', 'igae_secun']]
# Out:
#                   imai  igae_secun
# 2004-01-01  100.000000  100.000000
# 2005-01-01  102.150266  102.150266
# 2006-01-01  106.368637  106.368637
# 2007-01-01  107.354181  107.354181
# 2008-01-01  106.227559  106.227559
# 2009-01-01   98.286279   98.286279
# 2010-01-01  102.744674  102.744674
# 2011-01-01  105.672056  105.672056
# 2012-01-01  108.677955  108.677955
# 2013-01-01  108.435427  108.435427
# 2014-01-01  111.233191  111.233191
# 2015-01-01  112.605275  112.605275
# 2016-01-01  113.031970  113.031970
# 2017-01-01  112.746275  112.746275
# 2018-01-01  112.942098  112.942098

# %%
# Hacemos grafica de ingresos del gobierno federal, ingresos tributarios, no tributarios y pib
descriptive.plot_series(df = yearly_index, 
                        cols = ['ing_gob_fed_neto_(mdp)_r',
                                'ing_no_trib_neto_(mdp)_r',
                                'ing_trib_neto_(mdp)_r',
                                'ing_trib_sin_gasol_neto_(mdp)_r',
                                'pibr_2019'],
                        legend= ['Ingresos totales',
                                 'Ingresos no tributarios',
                                 'Ingresos tributarios',
                                 'Ingresos tributarios sin gasolina',
                                 'PIB'],
                        title = 'Indice de ingresos del Gobierno Federal netos y del Producto Interno Bruto',
                        subtitle = 'Valores reales (2005 = 100)',
                        ticks='yearly',
                        dpi=200,
                        hline=100,
                        save_to='../figures/indice_pib_ingresos_netos.png')

# %%
descriptive.plot_series(df = yearly_index, 
                        cols = ['ing_trib_sin_gasol_neto_(mdp)_r',
                                'isr_neto_(mdp)_r',
                                'iva_neto_(mdp)_r',
                                'ieps_sin_gas_neto_(mdp)_r',
                                'pibr_2019'],
                        title = 'Indice de ingresos tributarios netos sin IEPS gasolina y del Producto Interno Bruto',
                        legend=['Ingresos tributarios sin IEPS gasolina',
                                'ISR',
                                'IVA',
                                'IEPS sin gasolina',
                                'PIB'],
                        subtitle = 'Valores reales (2005 = 100)',
                        ticks='yearly',
                        dpi = 200,
                        hline=100,
                        save_to='../figures/indice_pib_impuestos_netos.png')

# %%
descriptive.plot_series(df = yearly_index, 
                        cols = pibs,
                        title='Índice del Producto Interno Bruto de México y Estados Unidos',
                        legend=['México',
                                'Estados Unidos'],
                        subtitle='Valores reales (2005 = 100)',
                        ticks='yearly',
                        dpi=200,
                        hline=100,
                        save_to='../figures/indice_pib_usa_mex.png')

# %%
descriptive.plot_series(df = yearly_index, 
                        cols = precios,
                        title='Índices de precios de México y Estados Unidos',
                        legend=['México', 'Estados Unidos'],
                        subtitle = '(2014 = 100)',
                        dpi=100,
                        ticks='yearly',
                        hline=100)

# %%
descriptive.plot_series(df = yearly_index, 
                        cols = precios,
                        title='Índices de precios al consumidor de México y Estados Unidos',
                        legend=['México',
                                'Estados Unidos'],
                        ticks='yearly',
                        dpi=100,
                        save_to='../figures/precios_usa_mex.png')

# %%
igaes + indice_produccion_us + imai
# Out:
# ['igae', 'igae_prim', 'igae_secun', 'igae_terc', 'ind_prod_ind_us', 'imai']

# %%
descriptive.plot_series(df = yearly_index, 
                        cols = imai + igaes + indice_produccion_us ,
                        title= 'Indicadores de actividad económica de México y Estados Unidos',
                        legend=['IGAE',
                                'IGAE primario',
                                'IGAE secundario',
                                'IGAE terciario',
                                'Índice Producción Industrial Estados Unidos',
                                'IMAI'],
                        subtitle='(2005 = 100)',
                        ticks='yearly')

# %%
descriptive.plot_series(df = yearly_index, 
                        cols = indicadores_reales + indice_produccion_us,
                        title='Indicadores económicos de México y Estados Unidos',
                        legend=['Índice de Confianza a Consumidor en México', 
                                'Indicador mensual de consumo en México', 
                                'Indicador adelantado en México',
                                'Índice Producción Industrial Estados Unidos'],
                        subtitle='(2005 = 100)',
                        ticks='yearly')

# %% [markdown]
# ### Ingresos tributarios como % del PIB

# %%
fiscal_yearly_perc_pib = yearly[ingresos_tributarios_real].apply(lambda x: (x / yearly['pibr_2019']) * 100)

# %%
descriptive.plot_series(df = fiscal_yearly_perc_pib, 
                        cols = ['ing_trib_sin_gasol_neto_(mdp)_r',
                                'isr_neto_(mdp)_r',
                                'iva_neto_(mdp)_r',
                                'ieps_sin_gas_neto_(mdp)_r'],
                        title = 'Ingresos tributarios netos sin IEPS gasolina',
                        subtitle = '(% del PIB)',
                        legend= ['Ingresos tributarios sin IEPS gasolina',
                                'ISR',
                                'IVA',
                                'IEPS sin gasolina'],
                        ticks='yearly',
                        dpi=200,
                        save_to='../figures/impuestos_netos_perc_pib.png')

# %% [markdown]
# Elasticidad anual de Ingresos Tributarios a PIB

# %%
incremento_anual_tx = yearly[impuestos_netos].pct_change()
incremento_anual_pib = yearly['pibr_2019'].pct_change()
elasticidad_ingresos = incremento_anual_tx.div(incremento_anual_pib, axis=0)

# %%
yearly
# Out:
#                   igae   igae_prim  igae_secun   igae_terc        pea  \
# 2004-01-01   83.637738   88.338233   92.220783   78.723453        NaN
# 2005-01-01   85.594865   85.017442   94.203775   80.932505  59.300739
# 2006-01-01   89.363112   90.663757   98.093990   84.539626  60.084842
# 2007-01-01   91.482932   94.465728   99.002866   87.234570  60.050078
# 2008-01-01   92.392167   94.697277   97.963887   89.239650  59.901293
# 2009-01-01   87.350166   92.577416   90.640376   85.293684  59.868840
# 2010-01-01   91.696445   94.929450   94.751943   89.868387  59.631460
# 2011-01-01   95.152760   91.285778   97.451597   94.094904  59.727366
# 2012-01-01   98.641765   97.486554  100.223661   97.837930  60.371198
# 2013-01-01  100.000000  100.000000  100.000000  100.000000  60.342384
# 2014-01-01  102.573983  103.337231  102.580120  102.532169  59.803166
# 2015-01-01  105.782406  104.770763  103.845466  106.888940  59.812093
# 2016-01-01  108.671280  108.485282  104.238968  111.096063  59.655030
# 2017-01-01  110.823585  112.201441  103.975498  114.486033  59.281378
# 2018-01-01  112.951696  115.309498  104.156087  117.626064  59.535919
#
#             pobl_ocupada  confianza_consumidor  indic_mens_consumo  \
# 2004-01-01           NaN             96.819899           86.828499
# 2005-01-01     96.519223            102.030169           89.134754
# 2006-01-01     96.471597            109.221897           92.687135
# 2007-01-01     96.384573            104.864885           95.029705
# 2008-01-01     96.115570             92.195655           95.757057
# 2009-01-01     94.660827             80.485084           90.014103
# 2010-01-01     94.725035             86.310709           93.111200
# 2011-01-01     94.824529             91.707722           96.066708
# 2012-01-01     95.111672             95.833037           98.347583
# 2013-01-01     95.092724             94.498139          100.000000
# 2014-01-01     95.171042             89.898477          102.305303
# 2015-01-01     95.647057             91.861391          105.579130
# 2016-01-01     96.117562             88.191500          110.095506
# 2017-01-01     96.580954             84.628602          113.595049
# 2018-01-01     96.671451             94.639179          116.108241
#
#             indic_adelant       inpc  tc_mensual  indice_tc_real  \
# 2004-01-01      78.441667  55.018734   11.285858       77.075975
# 2005-01-01      82.425000  57.212914   10.893892       73.641083
# 2005-01-01          3.029396                   1.629987
# 2006-01-01          2.788230                   0.803555
# 2007-01-01          5.693106                   3.503578
# 2008-01-01          1.375406                  11.075803
# 2009-01-01          1.869391                   1.630808
# 2010-01-01          2.461566                   4.496045
# 2011-01-01          3.051911                   2.846396
# 2012-01-01          0.333651                   0.320572
# 2013-01-01          6.563416                   2.775168
# 2014-01-01          1.797817                  18.653607
# 2015-01-01          9.020413                   1.510130
# 2016-01-01          3.795099                  -0.947688
# 2017-01-01          1.153267                   3.024956
# 2018-01-01          1.249714                   0.333207

# %% [markdown]
# # Calculamos elasticidad de Largo Plazo

# %%
colnames = df_netos.columns
new_colnames = [col.replace('(', '').replace(')', '') for col in colnames]
df_netos.columns = new_colnames

# %%
elasticities = []

# %%
for col in ['ingresos_gobierno_federal_neto_mdp_r',\
            'ingresos_tributarios_neto_sin_gasol_mdp_r',\
            'isr_neto_mdp_r',\
            'iva_neto_mdp_r',\
            'ieps_neto_sin_gasol_mdp_r']:
    for covars in ['', '+ np.log(tc_mensual)', '+ np.log(tc_mensual) + np.log(inpc)']:
        reg = smf.ols(formula='np.log({}) ~ np.log(igae) {}'.format(col, covars), data=df_netos).fit()
        print(reg.summary())
        print(reg.pvalues['np.log(igae)'])
        elasticities.append({'ingresos': col, 
                             'covars': covars,
                             'coef': round(reg.params['np.log(igae)'], 3),
                             'std_err': round(reg.bse['np.log(igae)'], 3),
                             'pval': round(reg.pvalues['np.log(igae)'], 3)})
# Out:
#                                          OLS Regression Results
# ========================================================================================================
# Dep. Variable:     np.log(ingresos_gobierno_federal_neto_mdp_r)   R-squared:                       0.430
# Model:                                                      OLS   Adj. R-squared:                  0.427
# Method:                                           Least Squares   F-statistic:                     128.5
# Date:                                          Wed, 10 Jul 2019   Prob (F-statistic):           1.53e-22
# Time:                                                  16:30:57   Log-Likelihood:                 60.953
# No. Observations:                                           172   AIC:                            -117.9
# Df Residuals:                                               170   BIC:                            -111.6
# Df Model:                                                     1
# Covariance Type:                                      nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        5.2693      0.638      8.256      0.000       4.009       6.529
# np.log(igae)     1.5780      0.139     11.335      0.000       1.303       1.853
# ==============================================================================
# Omnibus:                       43.101   Durbin-Watson:                   1.752
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               98.271
# Skew:                           1.093   Prob(JB):                     4.58e-22
# Kurtosis:                       5.988   Cond. No.                         235.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 1.532877610404873e-22
#                                          OLS Regression Results
# ========================================================================================================
# Dep. Variable:     np.log(ingresos_gobierno_federal_neto_mdp_r)   R-squared:                       0.452
# Model:                                                      OLS   Adj. R-squared:                  0.445
# Method:                                           Least Squares   F-statistic:                     69.58
# Date:                                          Wed, 10 Jul 2019   Prob (F-statistic):           9.01e-23
# Time:                                                  16:30:57   Log-Likelihood:                 64.204
# No. Observations:                                           172   AIC:                            -122.4
# Df Residuals:                                               169   BIC:                            -113.0
# Df Model:                                                     2
# Covariance Type:                                      nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              6.9857      0.920      7.590      0.000       5.169       8.803
# np.log(igae)           1.0391      0.252      4.128      0.000       0.542       1.536
# np.log(tc_mensual)     0.2880      0.113      2.552      0.012       0.065       0.511
# ==============================================================================
# Omnibus:                       40.078   Durbin-Watson:                   1.815
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               82.687
# Skew:                           1.061   Prob(JB):                     1.11e-18
# Kurtosis:                       5.653   Cond. No.                         401.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 5.736832785016356e-05
#                                          OLS Regression Results
# ========================================================================================================
# Dep. Variable:     np.log(ingresos_gobierno_federal_neto_mdp_r)   R-squared:                       0.472
# Model:                                                      OLS   Adj. R-squared:                  0.462
# Method:                                           Least Squares   F-statistic:                     50.02
# Date:                                          Wed, 10 Jul 2019   Prob (F-statistic):           3.74e-23
# Time:                                                  16:30:57   Log-Likelihood:                 67.431
# No. Observations:                                           172   AIC:                            -126.9
# Df Residuals:                                               168   BIC:                            -114.3
# Df Model:                                                     3
# Covariance Type:                                      nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              7.5931      0.937      8.103      0.000       5.743       9.443
# np.log(igae)           0.4578      0.338      1.356      0.177      -0.209       1.124
# np.log(tc_mensual)     0.0738      0.140      0.529      0.598      -0.202       0.349
# np.log(inpc)           0.6063      0.239      2.534      0.012       0.134       1.079
# ==============================================================================
# Omnibus:                       50.580   Durbin-Watson:                   1.866
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              120.765
# Skew:                           1.268   Prob(JB):                     5.97e-27
# Kurtosis:                       6.228   Cond. No.                         540.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.17690391078431894
#                                             OLS Regression Results
# =============================================================================================================
# Dep. Variable:     np.log(ingresos_tributarios_neto_sin_gasol_mdp_r)   R-squared:                       0.647
# Model:                                                           OLS   Adj. R-squared:                  0.645
# Method:                                                Least Squares   F-statistic:                     311.0
# Date:                                               Wed, 10 Jul 2019   Prob (F-statistic):           3.05e-40
# Time:                                                       16:30:57   Log-Likelihood:                 76.922
# No. Observations:                                                172   AIC:                            -149.8
# Df Residuals:                                                    170   BIC:                            -143.5
# Df Model:                                                          1
# Covariance Type:                                           nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        1.7940      0.582      3.084      0.002       0.646       2.942
# np.log(igae)     2.2374      0.127     17.636      0.000       1.987       2.488
# ==============================================================================
# Omnibus:                       14.631   Durbin-Watson:                   1.457
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.011
# Skew:                           0.738   Prob(JB):                     0.000334
# Kurtosis:                       3.233   Cond. No.                         235.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 3.047417040876373e-40
#                                             OLS Regression Results
# =============================================================================================================
# Dep. Variable:     np.log(ingresos_tributarios_neto_sin_gasol_mdp_r)   R-squared:                       0.714
# Model:                                                           OLS   Adj. R-squared:                  0.710
# Method:                                                Least Squares   F-statistic:                     210.7
# Date:                                               Wed, 10 Jul 2019   Prob (F-statistic):           1.23e-46
# Time:                                                       16:30:57   Log-Likelihood:                 95.059
# No. Observations:                                                172   AIC:                            -184.1
# Df Residuals:                                                    169   BIC:                            -174.7
# Df Model:                                                          2
# Covariance Type:                                           nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              5.3351      0.769      6.936      0.000       3.817       6.854
# np.log(igae)           1.1257      0.210      5.351      0.000       0.710       1.541
# np.log(tc_mensual)     0.5942      0.094      6.299      0.000       0.408       0.780
# ==============================================================================
# Omnibus:                       19.073   Durbin-Watson:                   1.564
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.854
# Skew:                           0.843   Prob(JB):                     1.80e-05
# Kurtosis:                       3.455   Cond. No.                         401.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 2.819972028737203e-07
#                                             OLS Regression Results
# =============================================================================================================
# Dep. Variable:     np.log(ingresos_tributarios_neto_sin_gasol_mdp_r)   R-squared:                       0.745
# Model:                                                           OLS   Adj. R-squared:                  0.741
# Method:                                                Least Squares   F-statistic:                     163.9
# Date:                                               Wed, 10 Jul 2019   Prob (F-statistic):           1.13e-49
# Time:                                                       16:30:57   Log-Likelihood:                 105.11
# No. Observations:                                                172   AIC:                            -202.2
# Df Residuals:                                                    168   BIC:                            -189.6
# Df Model:                                                          3
# Covariance Type:                                           nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              6.2135      0.753      8.254      0.000       4.727       7.700
# np.log(igae)           0.2850      0.271      1.051      0.295      -0.250       0.820
# np.log(tc_mensual)     0.2844      0.112      2.537      0.012       0.063       0.506
# np.log(inpc)           0.8768      0.192      4.563      0.000       0.497       1.256
# ==============================================================================
# Omnibus:                       20.813   Durbin-Watson:                   1.621
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.658
# Skew:                           0.912   Prob(JB):                     4.42e-06
# Kurtosis:                       3.340   Cond. No.                         540.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.2948456894445553
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     np.log(isr_neto_mdp_r)   R-squared:                       0.592
# Model:                                OLS   Adj. R-squared:                  0.589
# Method:                     Least Squares   F-statistic:                     246.3
# Date:                    Wed, 10 Jul 2019   Prob (F-statistic):           6.82e-35
# Time:                            16:30:57   Log-Likelihood:                 17.474
# No. Observations:                     172   AIC:                            -30.95
# Df Residuals:                         170   BIC:                            -24.65
# Df Model:                               1
# Covariance Type:                nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -1.4751      0.822     -1.795      0.074      -3.097       0.147
# np.log(igae)     2.8133      0.179     15.695      0.000       2.459       3.167
# ==============================================================================
# Omnibus:                        8.560   Durbin-Watson:                   1.271
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):                8.979
# Skew:                           0.558   Prob(JB):                       0.0112
# Kurtosis:                       2.919   Cond. No.                         235.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 6.820774118633777e-35
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     np.log(isr_neto_mdp_r)   R-squared:                       0.670
# Model:                                OLS   Adj. R-squared:                  0.666
# Method:                     Least Squares   F-statistic:                     171.3
# Date:                    Wed, 10 Jul 2019   Prob (F-statistic):           2.28e-41
# Time:                            16:30:57   Log-Likelihood:                 35.688
# No. Observations:                     172   AIC:                            -65.38
# Df Residuals:                         169   BIC:                            -55.93
# Df Model:                               2
# Covariance Type:                nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              3.5377      1.086      3.257      0.001       1.393       5.682
# np.log(igae)           1.2396      0.297      4.172      0.000       0.653       1.826
# np.log(tc_mensual)     0.8411      0.133      6.314      0.000       0.578       1.104
# ==============================================================================
# Omnibus:                       15.086   Durbin-Watson:                   1.387
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.768
# Skew:                           0.760   Prob(JB):                     0.000228
# Kurtosis:                       3.165   Cond. No.                         401.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 4.818131166477674e-05
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     np.log(isr_neto_mdp_r)   R-squared:                       0.715
# Model:                                OLS   Adj. R-squared:                  0.710
# Method:                     Least Squares   F-statistic:                     140.3
# Date:                    Wed, 10 Jul 2019   Prob (F-statistic):           1.54e-45
# Time:                            16:30:57   Log-Likelihood:                 48.311
# No. Observations:                     172   AIC:                            -88.62
# Df Residuals:                         168   BIC:                            -76.03
# Df Model:                               3
# Covariance Type:                nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              4.9179      1.047      4.696      0.000       2.850       6.985
# np.log(igae)          -0.0814      0.377     -0.216      0.830      -0.826       0.664
# np.log(tc_mensual)     0.3544      0.156      2.272      0.024       0.046       0.662
# np.log(inpc)           1.3778      0.267      5.154      0.000       0.850       1.906
# ==============================================================================
# Omnibus:                       23.473   Durbin-Watson:                   1.488
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.426
# Skew:                           0.953   Prob(JB):                     6.72e-07
# Kurtosis:                       3.579   Cond. No.                         540.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.8295030516640275
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     np.log(iva_neto_mdp_r)   R-squared:                       0.488
# Model:                                OLS   Adj. R-squared:                  0.485
# Method:                     Least Squares   F-statistic:                     162.1
# Date:                    Wed, 10 Jul 2019   Prob (F-statistic):           1.67e-26
# Time:                            16:30:57   Log-Likelihood:                 90.798
# No. Observations:                     172   AIC:                            -177.6
# Df Residuals:                         170   BIC:                            -171.3
# Df Model:                               1
# Covariance Type:                nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        4.1932      0.537      7.814      0.000       3.134       5.252
# np.log(igae)     1.4899      0.117     12.731      0.000       1.259       1.721
# ==============================================================================
# Omnibus:                       14.879   Durbin-Watson:                   1.811
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               17.329
# Skew:                           0.615   Prob(JB):                     0.000173
# Kurtosis:                       3.951   Cond. No.                         235.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 1.6722830744868173e-26
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     np.log(iva_neto_mdp_r)   R-squared:                       0.501
# Model:                                OLS   Adj. R-squared:                  0.495
# Method:                     Least Squares   F-statistic:                     84.84
# Date:                    Wed, 10 Jul 2019   Prob (F-statistic):           3.08e-26
# Time:                            16:30:57   Log-Likelihood:                 93.003
# No. Observations:                     172   AIC:                            -180.0
# Df Residuals:                         169   BIC:                            -170.6
# Df Model:                               2
# Covariance Type:                nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              5.3851      0.778      6.918      0.000       3.848       6.922
# np.log(igae)           1.1157      0.213      5.240      0.000       0.695       1.536
# np.log(tc_mensual)     0.2000      0.095      2.095      0.038       0.012       0.388
# ==============================================================================
# Omnibus:                       11.458   Durbin-Watson:                   1.770
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               13.055
# Skew:                           0.501   Prob(JB):                      0.00146
# Kurtosis:                       3.905   Cond. No.                         401.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 4.7298510589887854e-07
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     np.log(iva_neto_mdp_r)   R-squared:                       0.511
# Model:                                OLS   Adj. R-squared:                  0.503
# Method:                     Least Squares   F-statistic:                     58.58
# Date:                    Wed, 10 Jul 2019   Prob (F-statistic):           5.69e-26
# Time:                            16:30:57   Log-Likelihood:                 94.789
# No. Observations:                     172   AIC:                            -181.6
# Df Residuals:                         168   BIC:                            -169.0
# Df Model:                               3
# Covariance Type:                nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              5.7689      0.799      7.218      0.000       4.191       7.347
# np.log(igae)           0.7484      0.288      2.599      0.010       0.180       1.317
# np.log(tc_mensual)     0.0646      0.119      0.543      0.588      -0.170       0.300
# np.log(inpc)           0.3832      0.204      1.878      0.062      -0.020       0.786
# ==============================================================================
# Omnibus:                        9.768   Durbin-Watson:                   1.741
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               10.778
# Skew:                           0.451   Prob(JB):                      0.00457
# Kurtosis:                       3.830   Cond. No.                         540.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.010189032958518226
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     np.log(ieps_neto_sin_gasol_mdp_r)   R-squared:                       0.641
# Model:                                           OLS   Adj. R-squared:                  0.639
# Method:                                Least Squares   F-statistic:                     303.9
# Date:                               Wed, 10 Jul 2019   Prob (F-statistic):           1.09e-39
# Time:                                       16:30:57   Log-Likelihood:                -9.9851
# No. Observations:                                172   AIC:                             23.97
# Df Residuals:                                    170   BIC:                             30.27
# Df Model:                                          1
# Covariance Type:                           nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -7.7858      0.964     -8.076      0.000      -9.689      -5.883
# np.log(igae)     3.6657      0.210     17.433      0.000       3.251       4.081
# ==============================================================================
# Omnibus:                       34.234   Durbin-Watson:                   1.777
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               54.966
# Skew:                           1.031   Prob(JB):                     1.16e-12
# Kurtosis:                       4.848   Cond. No.                         235.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 1.0850409346045342e-39
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     np.log(ieps_neto_sin_gasol_mdp_r)   R-squared:                       0.673
# Model:                                           OLS   Adj. R-squared:                  0.669
# Method:                                Least Squares   F-statistic:                     174.2
# Date:                               Wed, 10 Jul 2019   Prob (F-statistic):           8.77e-42
# Time:                                       16:30:57   Log-Likelihood:                -1.9377
# No. Observations:                                172   AIC:                             9.875
# Df Residuals:                                    169   BIC:                             19.32
# Df Model:                                          2
# Covariance Type:                           nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             -3.7628      1.352     -2.783      0.006      -6.432      -1.094
# np.log(igae)           2.4027      0.370      6.498      0.000       1.673       3.133
# np.log(tc_mensual)     0.6750      0.166      4.072      0.000       0.348       1.002
# ==============================================================================
# Omnibus:                       34.670   Durbin-Watson:                   1.784
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               57.869
# Skew:                           1.021   Prob(JB):                     2.72e-13
# Kurtosis:                       4.976   Cond. No.                         401.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 8.77063028649711e-10
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     np.log(ieps_neto_sin_gasol_mdp_r)   R-squared:                       0.706
# Model:                                           OLS   Adj. R-squared:                  0.701
# Method:                                Least Squares   F-statistic:                     134.8
# Date:                               Wed, 10 Jul 2019   Prob (F-statistic):           1.68e-44
# Time:                                       16:30:57   Log-Likelihood:                 7.2649
# No. Observations:                                172   AIC:                            -6.530
# Df Residuals:                                    168   BIC:                             6.060
# Df Model:                                          3
# Covariance Type:                           nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             -2.2819      1.330     -1.716      0.088      -4.907       0.343
# np.log(igae)           0.9853      0.479      2.057      0.041       0.040       1.931
# np.log(tc_mensual)     0.1528      0.198      0.772      0.441      -0.238       0.544
# np.log(inpc)           1.4784      0.339      4.356      0.000       0.808       2.148
# ==============================================================================
# Omnibus:                       11.966   Durbin-Watson:                   1.825
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               17.790
# Skew:                           0.399   Prob(JB):                     0.000137
# Kurtosis:                       4.359   Cond. No.                         540.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.04123748400330529

# %%
elasticities_df = pd.DataFrame(elasticities)

# %%
elasticities_df = elasticities_df[['ingresos', 'covars', 'coef', 'std_err', 'pval']]
elasticities_df
# Out:
#                                      ingresos  \
# 0        ingresos_gobierno_federal_neto_mdp_r
# 1        ingresos_gobierno_federal_neto_mdp_r
# 2        ingresos_gobierno_federal_neto_mdp_r
# 3        ingresos_gobierno_federal_neto_mdp_r
# 4   ingresos_tributarios_neto_sin_gasol_mdp_r
# 5   ingresos_tributarios_neto_sin_gasol_mdp_r
# 6   ingresos_tributarios_neto_sin_gasol_mdp_r
# 7                              isr_neto_mdp_r
# 8                              isr_neto_mdp_r
# 9                              isr_neto_mdp_r
# 10                             iva_neto_mdp_r
# 11                             iva_neto_mdp_r
# 12                             iva_neto_mdp_r
# 13                  ieps_neto_sin_gasol_mdp_r
# 14                  ieps_neto_sin_gasol_mdp_r
# 15                  ieps_neto_sin_gasol_mdp_r
#
#                                  covars   coef  std_err   pval
# 0                                        1.578    0.139  0.000
# 1                                        1.578    0.139  0.000
# 2                  + np.log(tc_mensual)  1.039    0.252  0.000
# 3   + np.log(tc_mensual) + np.log(inpc)  0.458    0.338  0.177
# 4                                        2.237    0.127  0.000
# 5                  + np.log(tc_mensual)  1.126    0.210  0.000
# 6   + np.log(tc_mensual) + np.log(inpc)  0.285    0.271  0.295
# 7                                        2.813    0.179  0.000
# 8                  + np.log(tc_mensual)  1.240    0.297  0.000
# 9   + np.log(tc_mensual) + np.log(inpc) -0.081    0.377  0.830
# 10                                       1.490    0.117  0.000
# 11                 + np.log(tc_mensual)  1.116    0.213  0.000
# 12  + np.log(tc_mensual) + np.log(inpc)  0.748    0.288  0.010
# 13                                       3.666    0.210  0.000
# 14                 + np.log(tc_mensual)  2.403    0.370  0.000
# 15  + np.log(tc_mensual) + np.log(inpc)  0.985    0.479  0.041

# %% [markdown]
# # Crear mas variables

# %%
# Creamos dummies mensuales
df_netos['month'] = df_netos.index.map(lambda x: x.month)
inicios_sexenios = [2007, 2013, 2019]
df_netos['inicio_sexenio'] = np.where(df_netos.index.year.isin(inicios_sexenios), 1, 0)
fin_sexenios = [2006, 2018]
df_netos['fin_sexenio'] = np.where(df_netos.index.year.isin(fin_sexenios), 1, 0)

# %% [markdown]
# # Graficando indice de ingresos brutos

# %%
ingresos_sat = download.load_ingresos_fiscales_sat()
ingresos_sat_yearly = ingresos_sat.resample('YS').sum()

# %%
ingresos_sat_yearly = ingresos_sat_yearly.merge(pib_yearly, left_index=True, right_index=True)
ingresos_sat_yearly_index = ingresos_sat_yearly.apply(lambda x: (x / x.iloc[0]) * 100 )

# %%
ingresos_sat_yearly_index = ingresos_sat_yearly_index.loc[ingresos_sat_yearly_index.index < '2019-01-01']

# %%
ingresos_sat_yearly_index.columns

# %%
# Hacemos grafica de ingresos del gobierno federal, ingresos tributarios, no tributarios y pib
descriptive.plot_series(df = ingresos_sat_yearly_index, 
                        cols = ['ing_tot_brut_(mdp)_r',
                                'ing_trib_brut_(mdp)_r',
                                'ing_no_trib_bruto_(mdp)_r',
                                'pibr_2019'],
                        legend= ['Ingresos totales',
                                 'Ingresos tributarios',
                                 'Ingresos no tributarios',
                                 'PIB'],
                        title = 'Indice de ingresos del Gobierno Federal brutos y del Producto Interno Bruto',
                        subtitle = 'Valores reales (2014 = 100)',
                        ticks='yearly',
                        save_to='../figures/indice_pib_ingresos_brutos.png')

# %%
# Hacemos grafica de ingresos del gobierno federal, ingresos tributarios, no tributarios y pib
descriptive.plot_series(df = ingresos_sat_yearly_index, 
                        cols = ['ing_trib_brut_(mdp)_r',
                                'iva_bruto_(mdp)_r',
                                'isr_bruto_(mdp)_r',
                                'ieps_bruto_(mdp)_r',
                                'iva_neto_(mdp)_r',
                                'pibr_2019'],
                        legend= ['Ingresos totales',
                                 'IVA',
                                 'ISR',
                                 'IEPS',
                                 'IVA neto',
                                 'PIB'],
                        title = 'Indice de ingresos del Gobierno Federal brutos y del Producto Interno Bruto',
                        subtitle = 'Valores reales (2014 = 100)',
                        ticks='yearly',
                        save_to='../figures/indice_pib_impuestos_brutos.png')

# %% [markdown]
# # Calculando elasticidades

# %%
df_brutos = pd.merge(ingresos_sat, igae, left_index=True, right_index=True)
df_brutos = pd.merge(df_brutos, pib_r_df, left_index=True, right_index=True)
df_brutos = pd.merge(df_brutos, tc, left_index=True, right_index=True)

# %%
df_brutos_log = df_brutos.apply(np.log)
df_brutos_log = df_brutos_log.add_prefix('ln_')
columns = df_brutos_log.columns
newcolumns = [col.replace('(', '').replace(')', '') for col in  columns]
df_brutos_log.columns = newcolumns

# %%
df_brutos_log.columns

# %%
for col in ['ln_ing_trib_brut_mdp_r',\
            'ln_iva_bruto_mdp_r',\
            'ln_isr_bruto_mdp_r',\
            'ln_ieps_bruto_mdp_r',\
            'ln_ing_trib_neto_mdp_r',\
            'ln_iva_neto_mdp_r',\
            'ln_isr_neto_mdp_r',\
            'ln_ieps_neto_mdp_r']:
    reg = smf.ols(formula='{} ~ ln_igae'.format(col), data=df_brutos_log).fit()
    print(reg.summary())
    elasticities['2014-2018'].append({col: {'coef': reg.params['ln_igae'], 'std_err': reg.bse['ln_igae']}})
