# %% [markdown]
# # Pipeline Analyze
# - Analyze results from predictions

# %%
# Configuraciones de Jupyter que sirven para que cambios en los scripts se actualicen automáticamente
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import download

# %%
import models_multivariate as mv
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
import itertools

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
# Parámetros del análisis
params= {
    'results_var_mx_no_trib': '../results/results_var_mx_no_trib.csv',
    'results_var_mx_trib': '../results/results_var_mx_w_trib.csv',
    'results_var_mx_trib_tot': '../results/results_var_mx_w_trib_tot_new.csv',
    'results_var': '../results/results_var.csv',
    'results_var_new': '../results/results_var_new.csv',
    'results_ml': '../results/results_ml.csv',
    'results_ml_new' : '../results/results_ML_new.csv',
    'results_ml_1000': '../results/results_ML_new_1000.csv',
    'results_arima': '../results/results_arima.csv',
    'results_arima_new': '../results/results_arima_new.csv',
    'results_arima_ing_tot': '../results/results_arima_new_ing_total.csv',
    'accuracy_meassure': 'rmse_first6'
}

# %%
# Importamos CSV's
results_var_mx_no_trib = pd.read_csv(params['results_var_mx_no_trib'])
results_var_mx_trib = pd.read_csv(params['results_var_mx_trib'])
results_var_mx_trib_tot = pd.read_csv(params['results_var_mx_trib_tot'])
results_var = pd.read_csv(params['results_var'])
results_var_new = pd.read_csv(params['results_var_new'])

results_ml = pd.read_csv(params['results_ml'])
results_ml['exog_vars'] = 'all'
results_ml_new = pd.read_csv(params['results_ml_new'])
results_ml_new['exog_vars'] = 'all_igae_sa'
results_ml_1000 = pd.read_csv(params['results_ml_1000'])
results_ml_1000['exog_vars'] = 'all_igae_sa'

results_arima = pd.read_csv(params['results_arima'])
results_arima_new = pd.read_csv(params['results_arima_new'])
results_arima_ing_tot = pd.read_csv(params['results_arima_ing_tot'])


results = pd.concat([results_var, results_var_new,
                     results_arima, results_arima_new, results_arima_ing_tot,
                     results_var_mx_no_trib, results_var_mx_trib, results_var_mx_trib_tot,
                     results_ml, results_ml_new, results_ml_1000], axis=0, sort=False)
results.drop('Unnamed: 0', axis=1, inplace=True)

# Organizamos el órden de las variables
var_order = [
 'model', 'params', 'endog_vars', 'exog_vars', 'variable', 'split_date','pred_period', 'forecast_biass_first6',
 'forecast_biass_first18', 'forecast_biass_last12', 'mape_first6', 'mape_first18', 'mape_last12', 'mae_first6',
 'mae_first18', 'mae_last12', 'rmse_first6', 'rmse_first18', 'rmse_last12']

results = results[var_order]
results = results.loc[results['split_date'] != '2019-07-01']

# %%
display(results.shape)
display(results.groupby('model').size())
# Out:
# (21468, 19)
# model
# ARIMA     1651
# DT        9720
# GB        2637
# RF        3844
# SARIMA    2608
# VAR       1008
# dtype: int64

# %%
# Nos quedamos solo con los modelos que se pudieron estimar para los 4 cortes
number_of_models = results.groupby(['model', 'params', 'endog_vars', 'exog_vars', 'variable']).size().reset_index()
number_of_models = number_of_models.loc[number_of_models[0]==number_of_models[0].max()]
results_complete = number_of_models.merge(results, left_on=['model', 'params', 'endog_vars', 'exog_vars', 'variable'],
                                           right_on = ['model', 'params', 'endog_vars', 'exog_vars', 'variable'])
results_complete.drop(0, axis=1, inplace=True)

# %%
display(results_complete.shape)
display(results_complete.groupby('model').size())
# Out:
# (21356, 19)
# model
# ARIMA     1580
# DT        9720
# GB        2596
# RF        3844
# SARIMA    2608
# VAR       1008
# dtype: int64

# %% [markdown]
# Perdimos  especificaciones porque no pudieron ser estimadas para todos los cortes. De ellas,  fueron ARIMA y  Gradient Boostin.

# %%
# results_complete.loc[results_complete['model'] == 'RF'].groupby('params').mean().sort_values('mape_first6')

# %%
# results_complete.loc[(results_complete['exog_vars'] == 'all_igae_sa') &
#                      (results_complete['variable'] == 'importaciones_neto_(mdp)_r')].groupby(
#     'params').mean().sort_values('mape_first6')

# %%
# # Nos quedamos con los mejores modelos
# best_models = []
# for v, group_1 in results_complete.groupby('variable'):
#     for g, group_2 in group_1.groupby('model'):
#         for exog_var, group_3 in group_2.groupby('exog_vars'):
#             for endog_var, group_4 in group_3.groupby('endog_vars'):        
#                 df=group_4.groupby(['params']).mean()
#                 best = df.sort_values(params['accuracy_meassure']).reset_index().iloc[0]
#                 best_models.append({'variable':v, 'model': g, 'params': best['params'],
#                                     'exog_vars': exog_var, 'endog_vars': endog_var,
#                                     'mape_first6': best['mape_first6'], 'mape_first18': best['mape_first18'] ,
#                                     'mape_last12': best['mape_last12']})

                # Nos quedamos con los mejores modelos
best_models = []
for v, group_1 in results_complete.groupby('variable'):
    for g, group_2 in group_1.groupby('model'):
        df = group_2.groupby(['exog_vars', 'endog_vars', 'params']).mean()        
        best = df.sort_values(params['accuracy_meassure']).reset_index().iloc[0]
        best_models.append({'variable':v, 'model': g, 'params': best['params'],
                            'exog_vars': best['exog_vars'], 'endog_vars': best['endog_vars'],
                            'mape_first6': best['mape_first6'], 'mape_first18': best['mape_first18'] ,
                            'mape_last12': best['mape_last12'], 'rmse_first6': best['rmse_first6'],
                            'rmse_first18': best['rmse_first18'], 'rmse_last12': best['rmse_last12']})

# %%
best_models = pd.DataFrame(best_models)[['variable', 'model', 'params', 'endog_vars',
                                        'exog_vars', 'mape_first6',
                                        'mape_first18', 'mape_last12', 'rmse_first6',
                                        'rmse_last12', 'rmse_first18']]

# %%
variables_de_interes = ['ing_trib_neto_(mdp)_r', 'ing_trib_sin_gasol_neto_(mdp)_r',
                        'isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'importaciones_neto_(mdp)_r',
                       'ieps_sin_gas_neto_(mdp)_r']

# %%
best_models.loc[best_models['variable'].isin(variables_de_interes)].sort_values(
    ['variable', params['accuracy_meassure']]).to_excel('../results/tabla_resultados_rmse_first18.xlsx', index=False)

# %%
best_models.loc[best_models['variable'] == 'igae', 'endog_vars'].values
# Out:
# array(["['igae', 'tc_mensual', 'tasa_cetes_91_mensual', 'inpc', 'importaciones_r', 'indic_mens_consumo']"],
#       dtype=object)

# %%
# best_models[best_models['variable'].isin(variables_de_interes)].sort_values(['variable', params['accuracy_meassure']])\
#     .to_csv('../results/mejores_{}.csv'.format(params['accuracy_meassure']))

# %%
best_models[best_models['variable']=='importaciones_neto_(mdp)_r'].sort_values(['variable', params['accuracy_meassure']])\
    .values
# Out:
# array([['importaciones_neto_(mdp)_r', 'GB',
#         "{'learning_rate': 0.5, 'max_depth': 1, 'n_estimators': 50, 'random_state': 1234, 'subsample': 1.0}",
#         "['importaciones_neto_(mdp)_r']", 'all', 0.050402659135613426,
#         0.1407831284511348, 0.19999488449018762, 312.6699523839553,
#         1146.866460865826, 919.7765966051027],
#        ['importaciones_neto_(mdp)_r', 'RF',
#         "{'criterion': 'mse', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 1000, 'n_jobs': -1, 'random_state': 1234}",
#         "['importaciones_neto_(mdp)_r']", 'all', 0.06436194674808274,
#         0.11110630529992709, 0.13961027100886803, 381.86170420941744,
#         832.5823444466, 705.0533754144651],
#        ['importaciones_neto_(mdp)_r', 'DT',
#         "{'criterion': 'mse', 'max_depth': 10, 'max_features': None, 'min_samples_split': 2, 'random_state': 1234}",
#         "['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'importaciones_neto_(mdp)_r']",
#         'all', 0.07263486222032363, 0.11472275572026716,
#         0.13901912672005012, 416.24076083673344, 820.3512341603935,
#         701.308581048505],
#        ['importaciones_neto_(mdp)_r', 'SARIMA',
#         "{'enforce_invertibility': False, 'enforce_stationarity': False, 'order': (3, 0, 3), 'seasonal_order': (1, 0, 1, 12)}",
#         "['importaciones_neto_(mdp)_r']",
#         "['mes_1', 'mes_3', 'mes_4', 'mes_12', 'year_2009', 'year_2015', 'semana_santa', 'IVA', 'ISRP', 'ISRE']",
#         0.07263755568706393, 0.10093770428043722, 0.11350024905379225,
#         447.4655612427033, 713.448430972165, 678.9349650506604],
#        ['importaciones_neto_(mdp)_r', 'VAR',
#         "{'ic': 'aic', 'maxlags': 12, 'trend': 'c'}",
#         "['isr_neto_(mdp)_r', 'importaciones_neto_(mdp)_r']",
#         "['igae', 'inpc', 'tasa_cetes_91_mensual', 'tc_mensual', 'commodity_price_index', 'importaciones_r', 'indic_mens_consumo', 'mes_1', 'mes_3', 'mes_4', 'mes_12', 'year_2009', 'year_2015', 'semana_santa', 'IVA', 'ISRP', 'ISRE']",
#         0.09301359494266523, 0.11014341431508001, 0.11808119099042294,
#         572.989912831039, 767.1990012112517, 747.6809531892593],
#        ['importaciones_neto_(mdp)_r', 'ARIMA', "{'order': (4, 0, 5)}",
#         "['importaciones_neto_(mdp)_r']",
#         "['mes_1', 'mes_3', 'mes_4', 'mes_12', 'year_2009', 'year_2015', 'semana_santa', 'IVA', 'ISRP', 'ISRE']",
#         0.09747169027382924, 0.10286109229136478, 0.10511712069418384,
#         599.3601681971088, 694.8757883915304, 708.4159785780441]],
#       dtype=object)

# %% [markdown]
# # HASTA AQUI

# %% [markdown]
# # HASTA AQUI

# %% [markdown]
# # HASTA AQUI

# %% [markdown]
# # HASTA AQUI

# %% [markdown]
# # HASTA AQUI

# %% [markdown]
# # HASTA AQUI

# %%
# best_models.index=best_models['endog_vars']
# best_models.sort_values(['variable', 'mape_first6'])
# best_models = best_models.reset_index()

# %%
best_models.drop(['mape_first6', 'mape_first18', 'mape_last12',
                  'rmse_first6', 'rmse_first18', 'rmse_last12'], axis=1, inplace=True)
best_models = pd.merge(best_models, results_complete, left_on=['variable', 'model', 'params', 'exog_vars', 'endog_vars'], 
                       right_on=['variable', 'model', 'params', 'exog_vars', 'endog_vars'])

# %% [markdown]
# np.arange(0, len(best_mape))

# %%
best_models.loc[best_models['variable'] == 'isr_neto_(mdp)_r'].sort_values(params['accuracy_meassure'])
# Out:
#              variable   model  \
# 127  isr_neto_(mdp)_r  SARIMA
# 126  isr_neto_(mdp)_r  SARIMA
# 111  isr_neto_(mdp)_r   ARIMA
# 128  isr_neto_(mdp)_r     VAR
# 116  isr_neto_(mdp)_r      GB
# 131  isr_neto_(mdp)_r     VAR
# 109  isr_neto_(mdp)_r   ARIMA
# 114  isr_neto_(mdp)_r      DT
# 130  isr_neto_(mdp)_r     VAR
# 124  isr_neto_(mdp)_r  SARIMA
# 112  isr_neto_(mdp)_r      DT
# 108  isr_neto_(mdp)_r   ARIMA
# 123  isr_neto_(mdp)_r      RF
# 119  isr_neto_(mdp)_r      GB
# 110  isr_neto_(mdp)_r   ARIMA
# 125  isr_neto_(mdp)_r  SARIMA
# 120  isr_neto_(mdp)_r      RF
# 113  isr_neto_(mdp)_r      DT
# 129  isr_neto_(mdp)_r     VAR
# 118  isr_neto_(mdp)_r      GB
# 122  isr_neto_(mdp)_r      RF
# 121  isr_neto_(mdp)_r      RF
# 117  isr_neto_(mdp)_r      GB
# 115  isr_neto_(mdp)_r      DT
#
#                                                 params  \
# 127  {'enforce_invertibility': False, 'enforce_stat...
# 126  {'enforce_invertibility': False, 'enforce_stat...
# 111                               {'order': (1, 0, 4)}
# 128        {'ic': 'bic', 'maxlags': 12, 'trend': 'ct'}
# 116  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...
# 131        {'ic': 'bic', 'maxlags': 12, 'trend': 'ct'}
# 109                               {'order': (1, 0, 4)}
# 114  {'criterion': 'mae', 'max_depth': 5, 'max_feat...
# 130        {'ic': 'bic', 'maxlags': 12, 'trend': 'ct'}
# 124  {'enforce_invertibility': False, 'enforce_stat...
# 112  {'criterion': 'mae', 'max_depth': 5, 'max_feat...
# 108                               {'order': (1, 0, 4)}
# 123  {'criterion': 'mse', 'max_depth': 50, 'max_fea...
# 119  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...
# 110                               {'order': (1, 0, 4)}
# 125  {'enforce_invertibility': False, 'enforce_stat...
# 120  {'criterion': 'mse', 'max_depth': 50, 'max_fea...
# 113  {'criterion': 'mae', 'max_depth': 5, 'max_feat...
# 129        {'ic': 'bic', 'maxlags': 12, 'trend': 'ct'}
# 118  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...
# 122  {'criterion': 'mse', 'max_depth': 50, 'max_fea...
# 121  {'criterion': 'mse', 'max_depth': 50, 'max_fea...
# 117  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...
# 115  {'criterion': 'mae', 'max_depth': 5, 'max_feat...
#
#                                             endog_vars  \
# 127                               ['isr_neto_(mdp)_r']
# 126                               ['isr_neto_(mdp)_r']
# 111                               ['isr_neto_(mdp)_r']
# 128  ['isr_neto_(mdp)_r', 'importaciones_neto_(mdp)...
# 116  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# 131  ['isr_neto_(mdp)_r', 'importaciones_neto_(mdp)...
# 109                               ['isr_neto_(mdp)_r']
# 114                               ['isr_neto_(mdp)_r']
# 130  ['isr_neto_(mdp)_r', 'importaciones_neto_(mdp)...
# 124                               ['isr_neto_(mdp)_r']
# 112                               ['isr_neto_(mdp)_r']
# 108                               ['isr_neto_(mdp)_r']
# 123           ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r']
# 119  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# 110                               ['isr_neto_(mdp)_r']
# 125                               ['isr_neto_(mdp)_r']
# 120           ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r']
# 113                               ['isr_neto_(mdp)_r']
# 129  ['isr_neto_(mdp)_r', 'importaciones_neto_(mdp)...
# 118  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# 122           ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r']
# 121           ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r']
# 117  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# 115                               ['isr_neto_(mdp)_r']
#
#                                              exog_vars  split_date  \
# 127  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...  2018-07-01
# 126  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...  2017-07-01
# 111  ['mes_1', 'mes_3', 'mes_4', 'mes_12', 'year_20...  2018-07-01
# 128  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...  2015-07-01
# 116                                                all  2015-07-01
# 131  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...  2018-07-01
# 109  ['mes_1', 'mes_3', 'mes_4', 'mes_12', 'year_20...  2016-07-01
# 114                                                all  2017-07-01
# 130  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...  2017-07-01
# 124  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...  2015-07-01
# 112                                                all  2015-07-01
# 108  ['mes_1', 'mes_3', 'mes_4', 'mes_12', 'year_20...  2015-07-01
# 123                                                all  2018-07-01
# 119                                                all  2018-07-01
# 110  ['mes_1', 'mes_3', 'mes_4', 'mes_12', 'year_20...  2017-07-01
# 125  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...  2016-07-01
# 120                                                all  2015-07-01
# 113                                                all  2016-07-01
# 129  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...  2016-07-01
# 118                                                all  2017-07-01
# 122                                                all  2017-07-01
# 121                                                all  2016-07-01
# 117                                                all  2016-07-01
# 115                                                all  2018-07-01
#
#     pred_period  forecast_biass_first6  forecast_biass_first18  \
# 127        18MS           -1387.406868            -5177.661776
# 126        18MS           -1641.048390            -5697.797156
# 111        18MS            -544.283978             -779.430327
# 128        18MS            3024.091884             3926.132980
# 116        18MS            -410.302865            13913.792577
# 131        18MS           -4483.921840           -11631.147256
# 109        18MS            3312.058248             4095.677847
# 114        18MS           -1073.190869             9413.556570
# 130        18MS            1241.853867            -4473.054762
# 124        18MS           -2780.326544           -10300.744083
# 112        18MS           -5027.472336           -34363.360332
# 108        18MS            2628.467985             8673.257627
# 123        18MS           -3558.129171             -878.771617
# 119        18MS           -8222.446576            -7445.960191
# 110        18MS           -4172.471800            -2486.814611
# 125        18MS           -6565.764858           -19815.100207
# 120        18MS            4169.839487            12131.850051
# 113        18MS            -567.493253           -18265.814796
# 129        18MS           -1016.455222            -8267.085527
# 118        18MS          -10251.795692           -13585.822631
# 122        18MS            3706.322735             2191.261821
# 121        18MS           -5580.221817             1887.292598
# 117        18MS          -19110.975563           -42163.953113
# 115        18MS            6769.040325            31969.601994
#
#      forecast_biass_last12  mape_first6  mape_first18  mape_last12  \
# 127           -8967.916684     0.022609      0.055438     0.088268
# 126           -7726.171540     0.032290      0.062590     0.077740
# 111           -1014.576677     0.032767      0.085956     0.139146
# 128            4377.153527     0.037722      0.073669     0.091642
# 116           21075.840299     0.049411      0.119473     0.154503
# 131          -18778.372672     0.039937      0.087349     0.134760
# 109            4487.487646     0.042939      0.067928     0.080423
# 114           14656.930289     0.040956      0.115994     0.153514
# 130           -7330.509076     0.049115      0.062358     0.068980
# 124          -14060.952852     0.055360      0.092009     0.110334
# 112          -49031.304330     0.062726      0.329430     0.462782
# 108           11695.652448     0.064846      0.090600     0.103476
# 123            1800.585937     0.058176      0.081526     0.104877
# 119           -6669.473807     0.063971      0.084447     0.104924
# 110           -1643.986017     0.063217      0.074643     0.080356
# 125          -26439.767882     0.072560      0.166636     0.213675
# 120           16112.855333     0.074143      0.115153     0.135658
# 113          -27114.975568     0.048650      0.221412     0.307793
# 129          -11892.400680     0.070276      0.089172     0.098619
# 118          -15252.836100     0.085457      0.120735     0.138374
# 122            1433.731364     0.056270      0.083473     0.097074
# 121            5621.049805     0.108815      0.101984     0.098568
# 117          -53690.441888     0.153456      0.323406     0.408380
# 115           57170.163663     0.177415      0.265877     0.354338
#
#        mae_first6   mae_first18    mae_last12   rmse_first6  rmse_first18  \
# 127   3053.620589   7958.784357  12863.948124   4017.395148  10177.929225
# 126   3772.303763   8595.220531  11006.678914   5511.762025  10717.697646
# 111   4463.923029  12943.987140  21424.051252   5529.458503  18567.591465
# 128   4462.529511  11614.089034  15189.868795   5851.240474  21161.555290
# 116   5425.825351  17162.735186  23031.190104   6393.273258  24291.465155
# 131   5236.787910  12504.777527  19772.767144   6614.131877  16820.084297
# 109   5652.975647  10038.697900  12231.559027   6755.047725  14811.994121
# 114   5237.072012  16938.141528  22788.676286   6958.261928  23637.119529
# 130   6435.142987   8791.645042   9969.896070   7797.599165  10505.765222
# 124   5822.253349  11314.719684  14060.952852   7815.132379  14973.981819
# 112   6749.814438  42147.607579  59846.504150   8135.100177  55039.854250
# 108   7278.395788  13392.398292  16449.399544   8622.363361  22425.687587
# 123   7782.928747  12044.175836  16305.422924   8775.228460  16239.954152
# 119   8222.446576  12300.896940  16379.347303   9439.640956  14743.043379
# 110   7941.009033  10642.832018  11993.743510   9696.188269  14995.265710
# 125   8675.162659  22746.184015  29781.694693   9939.182890  29024.108909
# 120   8565.866273  17426.604681  21856.973885  10203.053315  29120.961021
# 113   6495.164706  29381.983856  40825.393431  10265.461510  37896.206330
# 129   9081.940405  11790.112123  13144.197983  10570.905687  15063.079919
# 118  10251.795692  15728.703407  18467.157265  11785.597380  19063.202538
# 122   7844.192445  12291.035523  14514.457062  12079.948918  16725.568704
# 121  13853.275346  14723.543269  15158.677231  14993.771933  19449.459726
# 117  19110.975563  42551.071392  54271.119307  20336.194041  49318.377229
# 115  24153.356667  40661.760165  57170.163663  26300.602347  48516.789381
#
#       rmse_last12
# 127  13821.759036
# 126  12534.504535
# 111  25669.748621
# 128  25585.125090
# 116  29405.372768
# 131  22849.151648
# 109  17500.783408
# 114  28528.256605
# 130  11625.634520
# 124  17486.910825
# 112  67163.892133
# 108  26780.489553
# 123  21224.221711
# 119  18590.530783
# 110  17037.574860
# 125  34845.439711
# 120  34928.418340
# 113  45842.053087
# 129  16866.313807
# 118  21809.593846
# 122  18618.657035
# 121  21331.095309
# 117  58665.774560
# 115  63372.202264

# %%
variables_de_interes = ['ing_trib_neto_(mdp)_r', 'ing_trib_sin_gasol_neto_(mdp)_r',
                        'isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'importaciones_neto_(mdp)_r',
                       'ieps_sin_gas_neto_(mdp)_r']
varname_dict = {'ing_trib_neto_(mdp)_r': 'Ingresos tributarios',
                'ing_trib_sin_gasol_neto_(mdp)_r': 'Ingresos tributarios sin gas',
                'isr_neto_(mdp)_r': 'ISR',
                'iva_neto_(mdp)_r': 'IVA',
                'importaciones_neto_(mdp)_r': 'Impuesto a las importaciones',
                'ieps_sin_gas_neto_(mdp)_r': 'IEPS sin gasolina'}

# %%
for var, df in best_models.loc[best_models['split_date'] < '2019-01-01'].groupby('variable'):
    if var not in variables_de_interes:
        continue
        
    summary_levels = pd.pivot_table(df,
                                    index=['model', 'exog_vars', 'split_date'],
                                    aggfunc='min',
                                    fill_value=0)
    summary_levels = summary_levels.reset_index()
    summary_levels['model_vars'] = summary_levels['model'] + summary_levels['exog_vars']
    fig, ax = plt.subplots(figsize=(15,8), dpi=100)
    sns.lineplot(x="split_date", y='mape_first6', hue='model',
                 data=summary_levels, ax=ax)
    ax.invert_yaxis()
    ax.set_xlabel("Comienzo de predicción", fontsize=12)
    ax.set_ylabel("Error absoluto porcentual medio")
    ax.set_title(varname_dict[var], fontsize=14)
    ax.grid()
#     plt.savefig('../reporte/figures/'+var+'_prec_cierre.png')
    plt.show()

# %%
best_models.to_excel('mejores_modelos_mensuales.xlsx', index=False)

# %%
best_models.groupby(['variable', 'model', 'params', 'exog_vars', 'endog_vars']).mean()[['mape_first6', 'mape_first18']]\
    .sort_values('mape_first6').sort_index(level=0)
# Out:
#                                                                                                                                                                                                  mape_first6  \
# variable                        model  params                                             exog_vars                                          endog_vars
# ieps_sin_gas_neto_(mdp)_r       ARIMA  {'order': (4, 0, 3)}                               ['igae', 'inpc', 'tasa_cetes_91_mensual', 'tc_m... ['ieps_sin_gas_neto_(mdp)_r']                          0.149797
#                                 DT     {'criterion': 'mae', 'max_depth': 20, 'max_feat... all                                                ['ieps_sin_gas_neto_(mdp)_r']                          0.339099
#                                 GB     {'learning_rate': 0.5, 'max_depth': 1, 'n_estim... all                                                ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_t...     0.362959
#                                 RF     {'criterion': 'mse', 'max_depth': 50, 'max_feat... all                                                ['ieps_sin_gas_neto_(mdp)_r']                          0.346159
#                                 SARIMA {'enforce_invertibility': False, 'enforce_stati... ['igae', 'inpc', 'tasa_cetes_91_mensual', 'tc_m... ['ieps_sin_gas_neto_(mdp)_r']                          0.157890
#                                 VAR    {'ic': 'aic', 'maxlags': 12, 'trend': 'ct'}        ['igae', 'inpc', 'tasa_cetes_91_mensual', 'tc_m... ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ieps_...     0.112415
# igae                            VAR    {'ic': 'aic', 'maxlags': 12, 'trend': 'ct'}        ['commodity_price_index', 'cons_price_index_us'... ['igae', 'tc_mensual', 'tasa_cetes_91_mensual',...     0.015709
# igae_sa                         VAR    {'ic': 'bic', 'maxlags': 12, 'trend': 'c'}         ['commodity_price_index', 'cons_price_index_us'... ['igae_sa', 'tc_mensual', 'tasa_cetes_91_mensua...     0.005039
# importaciones_neto_(mdp)_r      ARIMA  {'order': (4, 0, 3)}                               ['mes_1', 'mes_3', 'mes_4', 'mes_12', 'year_200... ['importaciones_neto_(mdp)_r']                         0.096684
#                                 DT     {'criterion': 'mae', 'max_depth': 1, 'max_featu... all                                                ['importaciones_neto_(mdp)_r']                         0.071747
#                                 GB     {'learning_rate': 0.5, 'max_depth': 1, 'n_estim... all                                                ['importaciones_neto_(mdp)_r']                         0.050403
#                                 RF     {'criterion': 'mse', 'max_depth': 50, 'max_feat... all                                                ['importaciones_neto_(mdp)_r']                         0.064362
#                                 SARIMA {'enforce_invertibility': False, 'enforce_stati... ['mes_1', 'mes_3', 'mes_4', 'mes_12', 'year_200... ['importaciones_neto_(mdp)_r']                         0.072638
#                                 VAR    {'ic': 'fpe', 'maxlags': 12, 'trend': 'c'}         ['igae', 'inpc', 'tasa_cetes_91_mensual', 'tc_m... ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'impor...     0.090538
# importaciones_r                 VAR    {'ic': 'bic', 'maxlags': 12, 'trend': 'c'}         ['commodity_price_index', 'cons_price_index_us'... ['igae', 'tc_mensual', 'tasa_cetes_91_mensual',...     0.048332
# indic_mens_consumo              VAR    {'ic': 'aic', 'maxlags': 12, 'trend': 'c'}         ['commodity_price_index', 'cons_price_index_us'... ['igae', 'tc_mensual', 'tasa_cetes_91_mensual',...     0.016146
# ing_trib_neto_(mdp)_r           ARIMA  {'order': (2, 0, 4)}                               ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', 't... ['ing_trib_neto_(mdp)_r']                              0.065324
#                                 GB     {'learning_rate': 0.1, 'max_depth': 5, 'n_estim... all_igae_sa                                        ['ing_trib_neto_(mdp)_r']                              0.082382
#                                 SARIMA {'enforce_invertibility': False, 'enforce_stati... ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', 't... ['ing_trib_neto_(mdp)_r']                              0.044305
#                                 VAR    {'ic': 'bic', 'maxlags': 12, 'trend': 'c'}         ['commodity_price_index', 'cons_price_index_us'... ['igae_sa', 'tc_mensual', 'tasa_cetes_91_mensua...     0.069356
# ing_trib_sin_gasol_neto_(mdp)_r ARIMA  {'order': (2, 0, 1)}                               ['mes_1', 'mes_3', 'mes_4', 'mes_12', 'year_200... ['ing_trib_sin_gasol_neto_(mdp)_r']                    0.047920
#                                 DT     {'criterion': 'friedman_mse', 'max_depth': 1, '... all                                                ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_t...     0.070761
#                                 GB     {'learning_rate': 0.5, 'max_depth': 5, 'n_estim... all                                                ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_t...     0.070854
#                                 RF     {'criterion': 'mae', 'max_depth': 50, 'max_feat... all                                                ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_t...     0.058260
#                                 SARIMA {'enforce_invertibility': False, 'enforce_stati... ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', 't... ['ing_trib_sin_gasol_neto_(mdp)_r']                    0.048620
#                                 VAR    {'ic': 'aic', 'maxlags': 12, 'trend': 'c'}         ['commodity_price_index', 'cons_price_index_us'... ['igae', 'tc_mensual', 'tasa_cetes_91_mensual',...     0.077495
# inpc                            VAR    {'ic': 'fpe', 'maxlags': 12, 'trend': 'ct'}        ['commodity_price_index', 'cons_price_index_us'... ['igae_sa', 'tc_mensual', 'tasa_cetes_91_mensua...     0.005601
# isr_neto_(mdp)_r                ARIMA  {'order': (1, 0, 4)}                               ['mes_1', 'mes_3', 'mes_4', 'mes_12', 'year_200... ['isr_neto_(mdp)_r']                                   0.050942
#                                 DT     {'criterion': 'mae', 'max_depth': 10, 'max_feat... all                                                ['isr_neto_(mdp)_r']                                   0.063233
#                                 GB     {'learning_rate': 0.1, 'max_depth': 5, 'n_estim... all                                                ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r']               0.087086
#                                 RF     {'criterion': 'mae', 'max_depth': 50, 'max_feat... all                                                ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r']               0.065612
#                                 SARIMA {'enforce_invertibility': False, 'enforce_stati... ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', 't... ['isr_neto_(mdp)_r']                                   0.045705
#                                 VAR    {'ic': 'bic', 'maxlags': 12, 'trend': 'ct'}        ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', 't... ['isr_neto_(mdp)_r', 'importaciones_neto_(mdp)_r']     0.049263
# iva_neto_(mdp)_r                ARIMA  {'order': (1, 0, 1)}                               ['mes_1', 'mes_3', 'mes_4', 'mes_12', 'year_200... ['iva_neto_(mdp)_r']                                   0.130650
#                                 DT     {'criterion': 'mae', 'max_depth': 1, 'max_featu... all                                                ['iva_neto_(mdp)_r']                                   0.132039
#                                 GB     {'learning_rate': 0.1, 'max_depth': 10, 'n_esti... all                                                ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r']               0.119259
#                                 RF     {'criterion': 'mae', 'max_depth': 50, 'max_feat... all                                                ['iva_neto_(mdp)_r']                                   0.117365
#                                 SARIMA {'enforce_invertibility': False, 'enforce_stati... ['mes_1', 'mes_3', 'mes_4', 'mes_12', 'year_200... ['iva_neto_(mdp)_r']                                   0.120138
#                                 VAR    {'ic': 'aic', 'maxlags': 12, 'trend': 'ct'}        ['igae', 'inpc', 'tasa_cetes_91_mensual', 'tc_m... ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'impor...     0.122175
# tasa_cetes_91_mensual           VAR    {'ic': 'bic', 'maxlags': 12, 'trend': 'c'}         ['commodity_price_index', 'cons_price_index_us'... ['igae_sa', 'tc_mensual', 'tasa_cetes_91_mensua...     0.057045
# tc_mensual                      VAR    {'ic': 'aic', 'maxlags': 12, 'trend': 'c'}         ['commodity_price_index', 'cons_price_index_us'... ['igae_sa', 'tc_mensual', 'tasa_cetes_91_mensua...     0.044657
#
#                                                                                                                                                                                                  mape_first18
# variable                        model  params                                             exog_vars                                          endog_vars
# ieps_sin_gas_neto_(mdp)_r       ARIMA  {'order': (4, 0, 3)}                               ['igae', 'inpc', 'tasa_cetes_91_mensual', 'tc_m... ['ieps_sin_gas_neto_(mdp)_r']                           0.148763
#                                 DT     {'criterion': 'mae', 'max_depth': 20, 'max_feat... all                                                ['ieps_sin_gas_neto_(mdp)_r']                           0.342516
#                                 GB     {'learning_rate': 0.5, 'max_depth': 1, 'n_estim... all                                                ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_t...      1.917292
#                                 RF     {'criterion': 'mse', 'max_depth': 50, 'max_feat... all                                                ['ieps_sin_gas_neto_(mdp)_r']                           0.369935
#                                 SARIMA {'enforce_invertibility': False, 'enforce_stati... ['igae', 'inpc', 'tasa_cetes_91_mensual', 'tc_m... ['ieps_sin_gas_neto_(mdp)_r']                           0.201724
#                                 VAR    {'ic': 'aic', 'maxlags': 12, 'trend': 'ct'}        ['igae', 'inpc', 'tasa_cetes_91_mensual', 'tc_m... ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ieps_...      0.185640
# igae                            VAR    {'ic': 'aic', 'maxlags': 12, 'trend': 'ct'}        ['commodity_price_index', 'cons_price_index_us'... ['igae', 'tc_mensual', 'tasa_cetes_91_mensual',...      0.020373
# igae_sa                         VAR    {'ic': 'bic', 'maxlags': 12, 'trend': 'c'}         ['commodity_price_index', 'cons_price_index_us'... ['igae_sa', 'tc_mensual', 'tasa_cetes_91_mensua...      0.005816
# importaciones_neto_(mdp)_r      ARIMA  {'order': (4, 0, 3)}                               ['mes_1', 'mes_3', 'mes_4', 'mes_12', 'year_200... ['importaciones_neto_(mdp)_r']                          0.109508
#                                 DT     {'criterion': 'mae', 'max_depth': 1, 'max_featu... all                                                ['importaciones_neto_(mdp)_r']                          0.116976
#                                 GB     {'learning_rate': 0.5, 'max_depth': 1, 'n_estim... all                                                ['importaciones_neto_(mdp)_r']                          0.140783
#                                 RF     {'criterion': 'mse', 'max_depth': 50, 'max_feat... all                                                ['importaciones_neto_(mdp)_r']                          0.111106
#                                 SARIMA {'enforce_invertibility': False, 'enforce_stati... ['mes_1', 'mes_3', 'mes_4', 'mes_12', 'year_200... ['importaciones_neto_(mdp)_r']                          0.100938
#                                 VAR    {'ic': 'fpe', 'maxlags': 12, 'trend': 'c'}         ['igae', 'inpc', 'tasa_cetes_91_mensual', 'tc_m... ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'impor...      0.111355
# importaciones_r                 VAR    {'ic': 'bic', 'maxlags': 12, 'trend': 'c'}         ['commodity_price_index', 'cons_price_index_us'... ['igae', 'tc_mensual', 'tasa_cetes_91_mensual',...      0.070895
# indic_mens_consumo              VAR    {'ic': 'aic', 'maxlags': 12, 'trend': 'c'}         ['commodity_price_index', 'cons_price_index_us'... ['igae', 'tc_mensual', 'tasa_cetes_91_mensual',...      0.019596
# ing_trib_neto_(mdp)_r           ARIMA  {'order': (2, 0, 4)}                               ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', 't... ['ing_trib_neto_(mdp)_r']                               0.078991
#                                 GB     {'learning_rate': 0.1, 'max_depth': 5, 'n_estim... all_igae_sa                                        ['ing_trib_neto_(mdp)_r']                               0.195613
#                                 SARIMA {'enforce_invertibility': False, 'enforce_stati... ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', 't... ['ing_trib_neto_(mdp)_r']                               0.082071
#                                 VAR    {'ic': 'bic', 'maxlags': 12, 'trend': 'c'}         ['commodity_price_index', 'cons_price_index_us'... ['igae_sa', 'tc_mensual', 'tasa_cetes_91_mensua...      0.084357
# ing_trib_sin_gasol_neto_(mdp)_r ARIMA  {'order': (2, 0, 1)}                               ['mes_1', 'mes_3', 'mes_4', 'mes_12', 'year_200... ['ing_trib_sin_gasol_neto_(mdp)_r']                     0.065659
#                                 DT     {'criterion': 'friedman_mse', 'max_depth': 1, '... all                                                ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_t...      0.110947
#                                 GB     {'learning_rate': 0.5, 'max_depth': 5, 'n_estim... all                                                ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_t...      0.188769
#                                 RF     {'criterion': 'mae', 'max_depth': 50, 'max_feat... all                                                ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_t...      0.070767
#                                 SARIMA {'enforce_invertibility': False, 'enforce_stati... ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', 't... ['ing_trib_sin_gasol_neto_(mdp)_r']                     0.069319
#                                 VAR    {'ic': 'aic', 'maxlags': 12, 'trend': 'c'}         ['commodity_price_index', 'cons_price_index_us'... ['igae', 'tc_mensual', 'tasa_cetes_91_mensual',...      0.064408
# inpc                            VAR    {'ic': 'fpe', 'maxlags': 12, 'trend': 'ct'}        ['commodity_price_index', 'cons_price_index_us'... ['igae_sa', 'tc_mensual', 'tasa_cetes_91_mensua...      0.012567
# isr_neto_(mdp)_r                ARIMA  {'order': (1, 0, 4)}                               ['mes_1', 'mes_3', 'mes_4', 'mes_12', 'year_200... ['isr_neto_(mdp)_r']                                    0.079782
#                                 DT     {'criterion': 'mae', 'max_depth': 10, 'max_feat... all                                                ['isr_neto_(mdp)_r']                                    0.231822
#                                 GB     {'learning_rate': 0.1, 'max_depth': 5, 'n_estim... all                                                ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r']                0.264969
#                                 RF     {'criterion': 'mae', 'max_depth': 50, 'max_feat... all                                                ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r']                0.099819
#                                 SARIMA {'enforce_invertibility': False, 'enforce_stati... ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', 't... ['isr_neto_(mdp)_r']                                    0.094169
#                                 VAR    {'ic': 'bic', 'maxlags': 12, 'trend': 'ct'}        ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', 't... ['isr_neto_(mdp)_r', 'importaciones_neto_(mdp)_r']      0.078137
# iva_neto_(mdp)_r                ARIMA  {'order': (1, 0, 1)}                               ['mes_1', 'mes_3', 'mes_4', 'mes_12', 'year_200... ['iva_neto_(mdp)_r']                                    0.116811
#                                 DT     {'criterion': 'mae', 'max_depth': 1, 'max_featu... all                                                ['iva_neto_(mdp)_r']                                    0.163114
#                                 GB     {'learning_rate': 0.1, 'max_depth': 10, 'n_esti... all                                                ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r']                0.116474
#                                 RF     {'criterion': 'mae', 'max_depth': 50, 'max_feat... all                                                ['iva_neto_(mdp)_r']                                    0.138304
#                                 SARIMA {'enforce_invertibility': False, 'enforce_stati... ['mes_1', 'mes_3', 'mes_4', 'mes_12', 'year_200... ['iva_neto_(mdp)_r']                                    0.122193
#                                 VAR    {'ic': 'aic', 'maxlags': 12, 'trend': 'ct'}        ['igae', 'inpc', 'tasa_cetes_91_mensual', 'tc_m... ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'impor...      0.110748
# tasa_cetes_91_mensual           VAR    {'ic': 'bic', 'maxlags': 12, 'trend': 'c'}         ['commodity_price_index', 'cons_price_index_us'... ['igae_sa', 'tc_mensual', 'tasa_cetes_91_mensua...      0.156043
# tc_mensual                      VAR    {'ic': 'aic', 'maxlags': 12, 'trend': 'c'}         ['commodity_price_index', 'cons_price_index_us'... ['igae_sa', 'tc_mensual', 'tasa_cetes_91_mensua...      0.091199

# %% [markdown]
# # Precisiones de cierre

# %%
precision_cierre_arima_tot = pd.read_csv('../results/precision_cierre_arima_ing_trib_ing_total.csv')
precision_cierre_arima_ing_trib = pd.read_csv('../results/precision_cierre_arima_ing_trib.csv')
estimacion_cierre_mod_tot = pd.read_csv('../results/estimacion_cierre_ml_modelototal.csv')
estimacion_cierre_ml_modelostotales = pd.read_csv('../results/estimacion_cierre_ml_modelostotales.csv')
precision_cierre_mx_var_no_trib = pd.read_csv('../results/precision_cierre_mx_var_no_trib.csv')
precision_cierre_mx_var_w_trib = pd.read_csv('../results/precision_cierre_mx_var_w_trib.csv')
precision_cierre_var_ing_trib = pd.read_csv('../results/precision_cierre_var_ing_trib.csv')
precision_cierre_var_mx_ing_trib= pd.read_csv('../results/precision_cierre_mx_var_w_trib_tot.csv')

# %%
y_precisions = pd.concat([precision_cierre_arima_tot, precision_cierre_arima_ing_trib, estimacion_cierre_mod_tot,
           estimacion_cierre_ml_modelostotales, precision_cierre_mx_var_no_trib, precision_cierre_mx_var_w_trib,
           precision_cierre_var_ing_trib, precision_cierre_var_mx_ing_trib], sort=False)

# %%
y_precisions.drop('Unnamed: 0', axis=1, inplace=True)
y_precisions = y_precisions.reset_index()
y_precisions.drop('index', axis=1, inplace=True)

# %%
y_precisions = y_precisions.melt(id_vars=['model', 'params', 'endog_vars', 'exog_vars', 'split_date'],
                  var_name='variable',
                  value_name='precision_cierre')

# %%
def split_yearly_precs(x, anio):
    if x != x:
        return (np.nan, np.nan)
    precisions = re.findall('[-\d]+\.\d+', x)
    return (float(precisions[anio]))
# Out:
# <>:4: DeprecationWarning: invalid escape sequence \d
# <>:4: DeprecationWarning: invalid escape sequence \d
# <>:4: DeprecationWarning: invalid escape sequence \d
# <ipython-input-366-5160314b9020>:4: DeprecationWarning: invalid escape sequence \d
#   precisions = re.findall('[-\d]+\.\d+', x)

# %%
y_precisions['cierre_0'] = y_precisions['precision_cierre'].map(lambda x: split_yearly_precs(x, 0))
y_precisions['cierre_1'] = y_precisions['precision_cierre'].map(lambda x: split_yearly_precs(x, 1))
y_precisions['abs_cierre_0'] = abs(y_precisions['cierre_0'])
y_precisions['abs_cierre_1'] = abs(y_precisions['cierre_1'])

# %%
y_precisions = y_precisions.loc[y_precisions['precision_cierre'].notna()]
y_precisions = y_precisions.loc[y_precisions['split_date'] != '2019-01-01']

# %%
cierre_best = y_precisions.loc[y_precisions['variable'] == 'importaciones_neto_(mdp)_r'].groupby(
    ['model', 'params', 'endog_vars', 'exog_vars']).mean().reset_index().sort_values('abs_cierre_0')
cierre_best.index = cierre_best['params']
cierre_best
# Out:
#                                                      model  \
# params
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...      GB
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...      GB
# {'order': (4, 0, 4)}                                 ARIMA
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...      GB
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...      GB
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...      GB
# {'order': (3, 0, 3)}                                 ARIMA
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...      GB
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'order': (4, 0, 3)}                                 ARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'order': (2, 0, 2)}                                 ARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'order': (3, 0, 2)}                                 ARIMA
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...      GB
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...      GB
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...      GB
# {'order': (2, 0, 3)}                                 ARIMA
# {'ic': 'bic', 'maxlags': 12, 'trend': 'ct'}            VAR
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'order': (4, 0, 3)}                                 ARIMA
# {'ic': 'bic', 'maxlags': 12, 'trend': 'c'}             VAR
# {'ic': 'aic', 'maxlags': 12, 'trend': 'c'}             VAR
# {'ic': 'fpe', 'maxlags': 12, 'trend': 'c'}             VAR
# {'order': (4, 0, 2)}                                 ARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'order': (3, 0, 2)}                                 ARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'order': (2, 0, 4)}                                 ARIMA
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...      GB
# {'order': (4, 0, 4)}                                 ARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'order': (2, 0, 4)}                                 ARIMA
# {'order': (2, 0, 2)}                                 ARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'order': (4, 0, 2)}                                 ARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'order': (3, 0, 3)}                                 ARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'order': (2, 0, 3)}                                 ARIMA
# {'order': (3, 0, 4)}                                 ARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...      GB
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...      GB
# {'order': (3, 0, 4)}                                 ARIMA
# {'ic': 'aic', 'maxlags': 12, 'trend': 'ct'}            VAR
# {'ic': 'fpe', 'maxlags': 12, 'trend': 'ct'}            VAR
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...      GB
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...      GB
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'enforce_invertibility': False, 'enforce_stati...  SARIMA
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...      GB
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...      GB
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...      GB
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...      GB
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...      GB
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...      GB
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...      GB
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...      GB
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...      GB
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...      GB
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...      GB
#
#                                                                                                params  \
# params
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...
# {'order': (4, 0, 4)}                                                             {'order': (4, 0, 4)}
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  {'learning_rate': 0.1, 'max_depth': 10, 'n_est...
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...  {'learning_rate': 0.5, 'max_depth': 5, 'n_esti...
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...
# {'order': (3, 0, 3)}                                                             {'order': (3, 0, 3)}
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...  {'learning_rate': 0.5, 'max_depth': 5, 'n_esti...
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'order': (4, 0, 3)}                                                             {'order': (4, 0, 3)}
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'order': (2, 0, 2)}                                                             {'order': (2, 0, 2)}
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'order': (3, 0, 2)}                                                             {'order': (3, 0, 2)}
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...
# {'order': (2, 0, 3)}                                                             {'order': (2, 0, 3)}
# {'ic': 'bic', 'maxlags': 12, 'trend': 'ct'}               {'ic': 'bic', 'maxlags': 12, 'trend': 'ct'}
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'order': (4, 0, 3)}                                                             {'order': (4, 0, 3)}
# {'ic': 'bic', 'maxlags': 12, 'trend': 'c'}                 {'ic': 'bic', 'maxlags': 12, 'trend': 'c'}
# {'ic': 'aic', 'maxlags': 12, 'trend': 'c'}                 {'ic': 'aic', 'maxlags': 12, 'trend': 'c'}
# {'ic': 'fpe', 'maxlags': 12, 'trend': 'c'}                 {'ic': 'fpe', 'maxlags': 12, 'trend': 'c'}
# {'order': (4, 0, 2)}                                                             {'order': (4, 0, 2)}
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'order': (3, 0, 2)}                                                             {'order': (3, 0, 2)}
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'order': (2, 0, 4)}                                                             {'order': (2, 0, 4)}
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  {'learning_rate': 0.1, 'max_depth': 10, 'n_est...
# {'order': (4, 0, 4)}                                                             {'order': (4, 0, 4)}
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'order': (2, 0, 4)}                                                             {'order': (2, 0, 4)}
# {'order': (2, 0, 2)}                                                             {'order': (2, 0, 2)}
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'order': (4, 0, 2)}                                                             {'order': (4, 0, 2)}
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'order': (3, 0, 3)}                                                             {'order': (3, 0, 3)}
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'order': (2, 0, 3)}                                                             {'order': (2, 0, 3)}
# {'order': (3, 0, 4)}                                                             {'order': (3, 0, 4)}
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  {'learning_rate': 0.1, 'max_depth': 10, 'n_est...
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  {'learning_rate': 0.1, 'max_depth': 10, 'n_est...
# {'order': (3, 0, 4)}                                                             {'order': (3, 0, 4)}
# {'ic': 'aic', 'maxlags': 12, 'trend': 'ct'}               {'ic': 'aic', 'maxlags': 12, 'trend': 'ct'}
# {'ic': 'fpe', 'maxlags': 12, 'trend': 'ct'}               {'ic': 'fpe', 'maxlags': 12, 'trend': 'ct'}
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...  {'learning_rate': 0.5, 'max_depth': 10, 'n_est...
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...  {'learning_rate': 0.5, 'max_depth': 10, 'n_est...
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'enforce_invertibility': False, 'enforce_stati...  {'enforce_invertibility': False, 'enforce_stat...
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...  {'learning_rate': 0.5, 'max_depth': 10, 'n_est...
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...  {'learning_rate': 0.5, 'max_depth': 10, 'n_est...
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  {'learning_rate': 0.1, 'max_depth': 10, 'n_est...
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  {'learning_rate': 0.1, 'max_depth': 10, 'n_est...
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...  {'learning_rate': 0.5, 'max_depth': 5, 'n_esti...
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...  {'learning_rate': 0.5, 'max_depth': 5, 'n_esti...
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...  {'learning_rate': 0.5, 'max_depth': 5, 'n_esti...
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...  {'learning_rate': 0.5, 'max_depth': 5, 'n_esti...
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...  {'learning_rate': 0.5, 'max_depth': 10, 'n_est...
#
#                                                                                            endog_vars  \
# params
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# {'order': (4, 0, 4)}                                                   ['importaciones_neto_(mdp)_r']
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# {'order': (3, 0, 3)}                                                   ['importaciones_neto_(mdp)_r']
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'order': (4, 0, 3)}                                                   ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'order': (2, 0, 2)}                                                   ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'order': (3, 0, 2)}                                                   ['importaciones_neto_(mdp)_r']
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...                     ['importaciones_neto_(mdp)_r']
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# {'order': (2, 0, 3)}                                                   ['importaciones_neto_(mdp)_r']
# {'ic': 'bic', 'maxlags': 12, 'trend': 'ct'}         ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ieps...
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'order': (4, 0, 3)}                                                   ['importaciones_neto_(mdp)_r']
# {'ic': 'bic', 'maxlags': 12, 'trend': 'c'}          ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ieps...
# {'ic': 'aic', 'maxlags': 12, 'trend': 'c'}          ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ieps...
# {'ic': 'fpe', 'maxlags': 12, 'trend': 'c'}          ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ieps...
# {'order': (4, 0, 2)}                                                   ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'order': (3, 0, 2)}                                                   ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'order': (2, 0, 4)}                                                   ['importaciones_neto_(mdp)_r']
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# {'order': (4, 0, 4)}                                                   ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'order': (2, 0, 4)}                                                   ['importaciones_neto_(mdp)_r']
# {'order': (2, 0, 2)}                                                   ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'order': (4, 0, 2)}                                                   ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'order': (3, 0, 3)}                                                   ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'order': (2, 0, 3)}                                                   ['importaciones_neto_(mdp)_r']
# {'order': (3, 0, 4)}                                                   ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# {'order': (3, 0, 4)}                                                   ['importaciones_neto_(mdp)_r']
# {'ic': 'aic', 'maxlags': 12, 'trend': 'ct'}         ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ieps...
# {'ic': 'fpe', 'maxlags': 12, 'trend': 'ct'}         ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ieps...
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'enforce_invertibility': False, 'enforce_stati...                     ['importaciones_neto_(mdp)_r']
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'impo...
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...  ['isr_neto_(mdp)_r', 'iva_neto_(mdp)_r', 'ing_...
#
#                                                                                             exog_vars  \
# params
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...                                               None
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...                                               None
# {'order': (4, 0, 4)}                                ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...                                               None
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...                                               None
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...                                               None
# {'order': (3, 0, 3)}                                ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...                                               None
# {'enforce_invertibility': False, 'enforce_stati...  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'enforce_invertibility': False, 'enforce_stati...  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'order': (4, 0, 3)}                                ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'enforce_invertibility': False, 'enforce_stati...  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'enforce_invertibility': False, 'enforce_stati...  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'order': (2, 0, 2)}                                ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'enforce_invertibility': False, 'enforce_stati...  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'order': (3, 0, 2)}                                ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...                                               None
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...                                               None
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...                                               None
# {'order': (2, 0, 3)}                                ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'ic': 'bic', 'maxlags': 12, 'trend': 'ct'}         ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'enforce_invertibility': False, 'enforce_stati...  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'enforce_invertibility': False, 'enforce_stati...  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'enforce_invertibility': False, 'enforce_stati...  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'enforce_invertibility': False, 'enforce_stati...  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'order': (4, 0, 3)}                                                              ['importaciones_r']
# {'ic': 'bic', 'maxlags': 12, 'trend': 'c'}          ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'ic': 'aic', 'maxlags': 12, 'trend': 'c'}          ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'ic': 'fpe', 'maxlags': 12, 'trend': 'c'}          ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'order': (4, 0, 2)}                                ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'enforce_invertibility': False, 'enforce_stati...                                ['importaciones_r']
# {'enforce_invertibility': False, 'enforce_stati...                                ['importaciones_r']
# {'enforce_invertibility': False, 'enforce_stati...                                ['importaciones_r']
# {'order': (3, 0, 2)}                                                              ['importaciones_r']
# {'enforce_invertibility': False, 'enforce_stati...                                ['importaciones_r']
# {'order': (2, 0, 4)}                                ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...                                               None
# {'order': (4, 0, 4)}                                                              ['importaciones_r']
# {'enforce_invertibility': False, 'enforce_stati...  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'enforce_invertibility': False, 'enforce_stati...  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'order': (2, 0, 4)}                                                              ['importaciones_r']
# {'order': (2, 0, 2)}                                                              ['importaciones_r']
# {'enforce_invertibility': False, 'enforce_stati...  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'order': (4, 0, 2)}                                                              ['importaciones_r']
# {'enforce_invertibility': False, 'enforce_stati...                                ['importaciones_r']
# {'enforce_invertibility': False, 'enforce_stati...                                ['importaciones_r']
# {'enforce_invertibility': False, 'enforce_stati...                                ['importaciones_r']
# {'order': (3, 0, 3)}                                                              ['importaciones_r']
# {'enforce_invertibility': False, 'enforce_stati...  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'enforce_invertibility': False, 'enforce_stati...                                ['importaciones_r']
# {'order': (2, 0, 3)}                                                              ['importaciones_r']
# {'order': (3, 0, 4)}                                ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'enforce_invertibility': False, 'enforce_stati...  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...                                               None
# {'enforce_invertibility': False, 'enforce_stati...  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...                                               None
# {'order': (3, 0, 4)}                                                              ['importaciones_r']
# {'ic': 'aic', 'maxlags': 12, 'trend': 'ct'}         ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'ic': 'fpe', 'maxlags': 12, 'trend': 'ct'}         ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'enforce_invertibility': False, 'enforce_stati...  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...
# {'enforce_invertibility': False, 'enforce_stati...                                ['importaciones_r']
# {'enforce_invertibility': False, 'enforce_stati...                                ['importaciones_r']
# {'enforce_invertibility': False, 'enforce_stati...                                ['importaciones_r']
# {'enforce_invertibility': False, 'enforce_stati...                                ['importaciones_r']
# {'enforce_invertibility': False, 'enforce_stati...                                ['importaciones_r']
# {'enforce_invertibility': False, 'enforce_stati...                                ['importaciones_r']
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...                                               None
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...                                               None
# {'enforce_invertibility': False, 'enforce_stati...                                ['importaciones_r']
# {'enforce_invertibility': False, 'enforce_stati...                                ['importaciones_r']
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...                                               None
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...                                               None
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...                                               None
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...                                               None
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...                                               None
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...                                               None
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...                                               None
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...                                               None
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...                                               None
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...                                               None
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...                                               None
#
#                                                         cierre_0  \
# params
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  5.699512e+02
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  1.582948e+02
# {'order': (4, 0, 4)}                                7.490068e+02
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  9.242463e+02
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim... -8.324168e+01
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  1.526779e+03
# {'order': (3, 0, 3)}                                1.338715e+03
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...  6.609693e+01
# {'enforce_invertibility': False, 'enforce_stati...  1.316947e+03
# {'enforce_invertibility': False, 'enforce_stati...  1.301389e+03
# {'order': (4, 0, 3)}                                1.693460e+02
# {'enforce_invertibility': False, 'enforce_stati...  1.352400e+03
# {'enforce_invertibility': False, 'enforce_stati...  1.298902e+03
# {'order': (2, 0, 2)}                               -7.101828e+02
# {'enforce_invertibility': False, 'enforce_stati...  7.381605e+02
# {'order': (3, 0, 2)}                               -5.138266e+02
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  7.658995e+02
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  2.113487e+03
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  6.674735e+02
# {'order': (2, 0, 3)}                                1.645584e+03
# {'ic': 'bic', 'maxlags': 12, 'trend': 'ct'}        -1.827548e+02
# {'enforce_invertibility': False, 'enforce_stati...  1.183392e+03
# {'enforce_invertibility': False, 'enforce_stati...  1.293417e+03
# {'enforce_invertibility': False, 'enforce_stati...  1.326492e+03
# {'enforce_invertibility': False, 'enforce_stati...  1.331976e+03
# {'order': (4, 0, 3)}                                1.764965e+03
# {'ic': 'bic', 'maxlags': 12, 'trend': 'c'}          4.934502e+02
# {'ic': 'aic', 'maxlags': 12, 'trend': 'c'}          7.078120e+02
# {'ic': 'fpe', 'maxlags': 12, 'trend': 'c'}          7.078120e+02
# {'order': (4, 0, 2)}                                5.844960e+02
# {'enforce_invertibility': False, 'enforce_stati...  1.186378e+03
# {'enforce_invertibility': False, 'enforce_stati...  1.112781e+03
# {'enforce_invertibility': False, 'enforce_stati...  1.130369e+03
# {'order': (3, 0, 2)}                                9.332659e+02
# {'enforce_invertibility': False, 'enforce_stati...  1.147352e+03
# {'order': (2, 0, 4)}                                1.589712e+03
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  1.247021e+03
# {'order': (4, 0, 4)}                                1.963672e+03
# {'enforce_invertibility': False, 'enforce_stati...  1.109623e+03
# {'enforce_invertibility': False, 'enforce_stati...  1.280344e+03
# {'order': (2, 0, 4)}                                9.948953e+02
# {'order': (2, 0, 2)}                                8.002035e+02
# {'enforce_invertibility': False, 'enforce_stati...  1.239602e+03
# {'order': (4, 0, 2)}                                1.231097e+03
# {'enforce_invertibility': False, 'enforce_stati...  1.396805e+03
# {'enforce_invertibility': False, 'enforce_stati...  1.445647e+03
# {'enforce_invertibility': False, 'enforce_stati...  1.447949e+03
# {'order': (3, 0, 3)}                                5.001175e+02
# {'enforce_invertibility': False, 'enforce_stati...  1.395929e+03
# {'enforce_invertibility': False, 'enforce_stati...  1.430077e+03
# {'order': (2, 0, 3)}                                2.131015e+03
# {'order': (3, 0, 4)}                                1.873682e+03
# {'enforce_invertibility': False, 'enforce_stati...  1.758718e+03
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  2.915050e+03
# {'enforce_invertibility': False, 'enforce_stati...  1.706424e+03
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  2.931329e+03
# {'order': (3, 0, 4)}                                1.742554e+03
# {'ic': 'aic', 'maxlags': 12, 'trend': 'ct'}        -8.001746e+02
# {'ic': 'fpe', 'maxlags': 12, 'trend': 'ct'}        -8.001746e+02
# {'enforce_invertibility': False, 'enforce_stati...  1.967908e+03
# {'enforce_invertibility': False, 'enforce_stati...  2.493349e+03
# {'enforce_invertibility': False, 'enforce_stati...  3.242892e+03
# {'enforce_invertibility': False, 'enforce_stati...  1.845925e+03
# {'enforce_invertibility': False, 'enforce_stati...  1.811046e+03
# {'enforce_invertibility': False, 'enforce_stati...  1.929012e+03
# {'enforce_invertibility': False, 'enforce_stati...  2.589919e+03
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...  3.535866e+03
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...  3.535866e+03
# {'enforce_invertibility': False, 'enforce_stati...  3.751581e+03
# {'enforce_invertibility': False, 'enforce_stati...  2.006581e+03
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti... -2.653649e+03
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti... -2.811874e+03
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  4.961312e+03
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  5.517452e+03
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  4.573685e+03
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...  1.543250e+04
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim... -4.332442e+03
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim... -1.968650e+03
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim... -1.272937e+05
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim... -1.971948e+06
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti... -1.496430e+08
#
#                                                         cierre_1  \
# params
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim... -1.376114e+04
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim... -5.310986e+03
# {'order': (4, 0, 4)}                               -5.708981e+03
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti... -4.547349e+03
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...  9.611766e+02
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim... -5.565566e+03
# {'order': (3, 0, 3)}                               -4.609295e+03
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...  1.440089e+03
# {'enforce_invertibility': False, 'enforce_stati... -7.173265e+03
# {'enforce_invertibility': False, 'enforce_stati... -7.083262e+03
# {'order': (4, 0, 3)}                               -7.072739e+03
# {'enforce_invertibility': False, 'enforce_stati... -6.640334e+03
# {'enforce_invertibility': False, 'enforce_stati... -6.394581e+03
# {'order': (2, 0, 2)}                               -8.991675e+03
# {'enforce_invertibility': False, 'enforce_stati... -3.107313e+03
# {'order': (3, 0, 2)}                               -8.620775e+03
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim... -1.301240e+07
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  8.081069e+02
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim... -2.983773e+03
# {'order': (2, 0, 3)}                               -4.058637e+03
# {'ic': 'bic', 'maxlags': 12, 'trend': 'ct'}        -1.054559e+04
# {'enforce_invertibility': False, 'enforce_stati... -5.092803e+03
# {'enforce_invertibility': False, 'enforce_stati... -4.971221e+03
# {'enforce_invertibility': False, 'enforce_stati... -5.154925e+03
# {'enforce_invertibility': False, 'enforce_stati... -5.073505e+03
# {'order': (4, 0, 3)}                               -3.038628e+03
# {'ic': 'bic', 'maxlags': 12, 'trend': 'c'}         -6.032618e+03
# {'ic': 'aic', 'maxlags': 12, 'trend': 'c'}         -2.762567e+03
# {'ic': 'fpe', 'maxlags': 12, 'trend': 'c'}         -2.762567e+03
# {'order': (4, 0, 2)}                               -6.023840e+03
# {'enforce_invertibility': False, 'enforce_stati... -7.092384e+03
# {'enforce_invertibility': False, 'enforce_stati... -7.577818e+03
# {'enforce_invertibility': False, 'enforce_stati... -7.394698e+03
# {'order': (3, 0, 2)}                               -4.669734e+03
# {'enforce_invertibility': False, 'enforce_stati... -7.092846e+03
# {'order': (2, 0, 4)}                               -4.244963e+03
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti... -4.713930e+03
# {'order': (4, 0, 4)}                               -2.857124e+03
# {'enforce_invertibility': False, 'enforce_stati... -3.636181e+03
# {'enforce_invertibility': False, 'enforce_stati... -3.406156e+03
# {'order': (2, 0, 4)}                               -4.488116e+03
# {'order': (2, 0, 2)}                               -4.818187e+03
# {'enforce_invertibility': False, 'enforce_stati... -3.443700e+03
# {'order': (4, 0, 2)}                               -4.005194e+03
# {'enforce_invertibility': False, 'enforce_stati... -3.506302e+03
# {'enforce_invertibility': False, 'enforce_stati... -3.262585e+03
# {'enforce_invertibility': False, 'enforce_stati... -3.474705e+03
# {'order': (3, 0, 3)}                               -5.334977e+03
# {'enforce_invertibility': False, 'enforce_stati... -3.527071e+03
# {'enforce_invertibility': False, 'enforce_stati... -3.576452e+03
# {'order': (2, 0, 3)}                               -8.472718e+03
# {'order': (3, 0, 4)}                               -1.020366e+04
# {'enforce_invertibility': False, 'enforce_stati... -1.949186e+03
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti... -2.616882e+03
# {'enforce_invertibility': False, 'enforce_stati... -1.872467e+03
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti... -3.040802e+03
# {'order': (3, 0, 4)}                               -9.327252e+03
# {'ic': 'aic', 'maxlags': 12, 'trend': 'ct'}        -1.269769e+04
# {'ic': 'fpe', 'maxlags': 12, 'trend': 'ct'}        -1.269769e+04
# {'enforce_invertibility': False, 'enforce_stati... -1.698681e+03
# {'enforce_invertibility': False, 'enforce_stati...  1.174976e+03
# {'enforce_invertibility': False, 'enforce_stati...  2.120256e+03
# {'enforce_invertibility': False, 'enforce_stati... -9.494211e+02
# {'enforce_invertibility': False, 'enforce_stati... -1.349917e+03
# {'enforce_invertibility': False, 'enforce_stati... -1.118349e+03
# {'enforce_invertibility': False, 'enforce_stati...  8.211447e+02
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...  2.446218e+02
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...  2.446218e+02
# {'enforce_invertibility': False, 'enforce_stati...  3.449001e+03
# {'enforce_invertibility': False, 'enforce_stati... -5.493393e+02
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti... -1.015019e+12
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti... -8.762776e+11
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim... -1.119713e+03
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  2.761732e+04
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti... -4.371677e+11
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...  4.427946e+04
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim... -1.551844e+10
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim... -5.118535e+11
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim... -5.033047e+07
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim... -4.937672e+03
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...  3.373091e+04
#
#                                                     abs_cierre_0  abs_cierre_1
# params
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  6.216055e+02  1.786306e+04
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  1.353724e+03  2.435376e+04
# {'order': (4, 0, 4)}                                1.367792e+03  1.204009e+04
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  1.558404e+03  1.596378e+04
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...  1.744872e+03  2.206881e+04
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  1.806528e+03  2.256141e+04
# {'order': (3, 0, 3)}                                1.854585e+03  1.148406e+04
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...  1.858840e+03  2.341633e+04
# {'enforce_invertibility': False, 'enforce_stati...  1.896061e+03  1.315739e+04
# {'enforce_invertibility': False, 'enforce_stati...  1.933122e+03  1.335899e+04
# {'order': (4, 0, 3)}                                1.961210e+03  1.369025e+04
# {'enforce_invertibility': False, 'enforce_stati...  1.966983e+03  1.312996e+04
# {'enforce_invertibility': False, 'enforce_stati...  1.978678e+03  1.308276e+04
# {'order': (2, 0, 2)}                                2.018975e+03  1.556357e+04
# {'enforce_invertibility': False, 'enforce_stati...  2.094704e+03  1.323977e+04
# {'order': (3, 0, 2)}                                2.103372e+03  1.521622e+04
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  2.109877e+03  1.303323e+07
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  2.113487e+03  1.718182e+04
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  2.119122e+03  2.102714e+04
# {'order': (2, 0, 3)}                                2.231181e+03  1.119005e+04
# {'ic': 'bic', 'maxlags': 12, 'trend': 'ct'}         2.273466e+03  1.555274e+04
# {'enforce_invertibility': False, 'enforce_stati...  2.321534e+03  1.286752e+04
# {'enforce_invertibility': False, 'enforce_stati...  2.328884e+03  1.254285e+04
# {'enforce_invertibility': False, 'enforce_stati...  2.337632e+03  1.265217e+04
# {'enforce_invertibility': False, 'enforce_stati...  2.354303e+03  1.263936e+04
# {'order': (4, 0, 3)}                                2.385505e+03  1.163122e+04
# {'ic': 'bic', 'maxlags': 12, 'trend': 'c'}          2.413915e+03  1.280239e+04
# {'ic': 'aic', 'maxlags': 12, 'trend': 'c'}          2.423266e+03  1.134247e+04
# {'ic': 'fpe', 'maxlags': 12, 'trend': 'c'}          2.423266e+03  1.134247e+04
# {'order': (4, 0, 2)}                                2.430071e+03  1.259969e+04
# {'enforce_invertibility': False, 'enforce_stati...  2.433896e+03  1.427761e+04
# {'enforce_invertibility': False, 'enforce_stati...  2.445365e+03  1.448752e+04
# {'enforce_invertibility': False, 'enforce_stati...  2.446589e+03  1.440006e+04
# {'order': (3, 0, 2)}                                2.461500e+03  1.268528e+04
# {'enforce_invertibility': False, 'enforce_stati...  2.477246e+03  1.439981e+04
# {'order': (2, 0, 4)}                                2.519448e+03  1.130716e+04
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  2.565435e+03  1.570485e+04
# {'order': (4, 0, 4)}                                2.624018e+03  1.162551e+04
# {'enforce_invertibility': False, 'enforce_stati...  2.664271e+03  1.321239e+04
# {'enforce_invertibility': False, 'enforce_stati...  2.678911e+03  1.305716e+04
# {'order': (2, 0, 4)}                                2.683709e+03  1.237026e+04
# {'order': (2, 0, 2)}                                2.729708e+03  1.287099e+04
# {'enforce_invertibility': False, 'enforce_stati...  2.754178e+03  1.317270e+04
# {'order': (4, 0, 2)}                                2.762302e+03  1.214384e+04
# {'enforce_invertibility': False, 'enforce_stati...  2.825873e+03  1.357099e+04
# {'enforce_invertibility': False, 'enforce_stati...  2.833620e+03  1.359378e+04
# {'enforce_invertibility': False, 'enforce_stati...  2.847920e+03  1.353607e+04
# {'order': (3, 0, 3)}                                2.853343e+03  1.323517e+04
# {'enforce_invertibility': False, 'enforce_stati...  2.863514e+03  1.292342e+04
# {'enforce_invertibility': False, 'enforce_stati...  2.870876e+03  1.358851e+04
# {'order': (2, 0, 3)}                                2.889145e+03  9.683038e+03
# {'order': (3, 0, 4)}                                2.896069e+03  1.062260e+04
# {'enforce_invertibility': False, 'enforce_stati...  2.906497e+03  1.201591e+04
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  2.915050e+03  1.484085e+04
# {'enforce_invertibility': False, 'enforce_stati...  2.918642e+03  1.195389e+04
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  2.931329e+03  1.445203e+04
# {'order': (3, 0, 4)}                                2.938460e+03  9.975268e+03
# {'ic': 'aic', 'maxlags': 12, 'trend': 'ct'}         2.984499e+03  1.364551e+04
# {'ic': 'fpe', 'maxlags': 12, 'trend': 'ct'}         2.984499e+03  1.364551e+04
# {'enforce_invertibility': False, 'enforce_stati...  3.082464e+03  1.177064e+04
# {'enforce_invertibility': False, 'enforce_stati...  3.298826e+03  1.223707e+04
# {'enforce_invertibility': False, 'enforce_stati...  3.325518e+03  1.278804e+04
# {'enforce_invertibility': False, 'enforce_stati...  3.342404e+03  1.382344e+04
# {'enforce_invertibility': False, 'enforce_stati...  3.346060e+03  1.387150e+04
# {'enforce_invertibility': False, 'enforce_stati...  3.361953e+03  1.368861e+04
# {'enforce_invertibility': False, 'enforce_stati...  3.419401e+03  1.208921e+04
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...  3.535866e+03  2.043298e+04
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...  3.535866e+03  2.043298e+04
# {'enforce_invertibility': False, 'enforce_stati...  3.751581e+03  1.364217e+04
# {'enforce_invertibility': False, 'enforce_stati...  3.938105e+03  1.445878e+04
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...  4.020670e+03  1.015019e+12
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...  4.137805e+03  8.762776e+11
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  4.961312e+03  2.249141e+04
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  5.695943e+03  2.761732e+04
# {'learning_rate': 0.1, 'max_depth': 10, 'n_esti...  8.006048e+03  4.371678e+11
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...  1.543627e+04  4.427946e+04
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...  1.706828e+04  1.551845e+10
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estim...  2.297180e+04  5.118536e+11
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...  1.466216e+05  5.035332e+07
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estim...  1.998816e+06  6.695970e+04
# {'learning_rate': 0.5, 'max_depth': 10, 'n_esti...  1.496602e+08  3.373480e+04

# %%
variable = 'ing_trib_neto_(mdp)_r'
model = 'SARIMA'
param = "{'enforce_invertibility': False, 'enforce_stationarity': False, 'order': (2, 0, 2), 'seasonal_order': (1, 0, 1, 12)}"

# %%
y_precisions.loc[(y_precisions['variable'] == variable) &
                (y_precisions['model'] == model) &
                (y_precisions['params'] == param)].sort_values('split_date')
# Out:
#      model                                             params  \
# 39  SARIMA  {'enforce_invertibility': False, 'enforce_stat...
# 55  SARIMA  {'enforce_invertibility': False, 'enforce_stat...
# 71  SARIMA  {'enforce_invertibility': False, 'enforce_stat...
# 87  SARIMA  {'enforce_invertibility': False, 'enforce_stat...
#
#                    endog_vars  \
# 39  ['ing_trib_neto_(mdp)_r']
# 55  ['ing_trib_neto_(mdp)_r']
# 71  ['ing_trib_neto_(mdp)_r']
# 87  ['ing_trib_neto_(mdp)_r']
#
#                                             exog_vars  split_date  \
# 39  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...  2015-07-01
# 55  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...  2016-07-01
# 71  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...  2017-07-01
# 87  ['igae_sa', 'inpc', 'tasa_cetes_91_mensual', '...  2018-07-01
#
#                  variable                                   precision_cierre  \
# 39  ing_trib_neto_(mdp)_r  {Timestamp('2015-01-01 00:00:00', freq='AS-JAN...
# 55  ing_trib_neto_(mdp)_r  {Timestamp('2016-01-01 00:00:00', freq='AS-JAN...
# 71  ing_trib_neto_(mdp)_r  {Timestamp('2017-01-01 00:00:00', freq='AS-JAN...
# 87  ing_trib_neto_(mdp)_r  {Timestamp('2018-01-01 00:00:00', freq='AS-JAN...
#
#         cierre_0      cierre_1  abs_cierre_0  abs_cierre_1
# 39 -45995.500691  1.795719e+05  45995.500691  1.795719e+05
# 55 -30324.300842 -5.068681e+05  30324.300842  5.068681e+05
# 71   8619.693699 -1.056369e+05   8619.693699  1.056369e+05
# 87 -48461.334241 -1.876467e+06  48461.334241  1.876467e+06

# %% [markdown]
# # Veamos el error de las estimaciones de la LIF

# %%
calendario_lif = download.load_calendario_lif()

# %%
ingresos_netos = download.load_ingresos_fiscales_netos()

# %%
calendario_lif.columns
# Out:
# Index(['ingresos_del_sector_public_presupuestado',
#        'ingresos_gobierno_federal_presupuestado',
#        'ingresos_tributarios_presupuestado', 'isr_presupuestado',
#        'iva_presupuestado', 'ieps_presupuestado',
#        'importaciones_presupuestado', 'otros impuestos_presupuestado',
#        'derechos_presupuestado', 'aprovechamientos_presupuestado',
#        'transferencias_fmp_presupuestado',
#        'otros no tributarios_presupuestado',
#        'ingresos_no_tributatios_presupuestado', 'inpc',
#        'ingresos_del_sector_public_presupuestado_r',
#        'ingresos_gobierno_federal_presupuestado_r',
#        'ingresos_tributarios_presupuestado_r', 'isr_presupuestado_r',
#        'iva_presupuestado_r', 'ieps_presupuestado_r',
#        'importaciones_presupuestado_r', 'otros impuestos_presupuestado_r',
#        'derechos_presupuestado_r', 'aprovechamientos_presupuestado_r',
#        'transferencias_fmp_presupuestado_r',
#        'otros no tributarios_presupuestado_r',
#        'ingresos_no_tributatios_presupuestado_r'],
#       dtype='object')

# %%
ingresos_netos.columns
# Out:
# Index(['ingresos_sector_publico_neto_(mdp)', 'ieps_neto_(mdp)',
#        'ieps_sin_gas_neto_(mdp)', 'ing_gob_fed_neto_(mdp)',
#        'ing_trib_neto_(mdp)', 'isr_neto_(mdp)', 'iva_neto_(mdp)',
#        'importaciones_neto_(mdp)', 'ing_no_trib_neto_(mdp)',
#        'ieps_hidrocarburos_neto_(mdp)', 'ieps_otros_petroliferos_neto_(mdp)',
#        'ieps_gasolina_neto_(mdp)', 'ieps_tabaco_neto_(mdp)',
#        'ieps_ba_neto_(mdp)', 'ieps_cerveza_neto_(mdp)',
#        'ieps_telecom_neto_(mdp)', 'ieps_otras_retenciones_neto_(mdp)',
#        'exportaciones_neto_(mdp)', 'isan_neto_(mdp)',
#        'accesorios_contribuciones_neto_(mdp)',
#        'otros_ingresos_tributarios_neto_(mdp)', 'ietu_neto_(mdp)',
#        'ide_neto_(mdp)', 'ieps_jys_neto_(mdp)', 'ieps_be_neto_(mdp)',
#        'ieps_bsaborizadas_neto_(mdp)', 'ieps_aadc_neto_(mdp)',
#        'ieps_plaguicidas_neto_(mdp)', 'ieps_combustibles_fosiles_neto_(mdp)',
#        'impuesto_extraccion_hidrocarburos_neto_(mdp)',
#        'ing_trib_sin_gasol_neto_(mdp)', 'inpc',
#        'ingresos_sector_publico_neto_(mdp)_r', 'ieps_neto_(mdp)_r',
#        'ieps_sin_gas_neto_(mdp)_r', 'ing_gob_fed_neto_(mdp)_r',
#        'ing_trib_neto_(mdp)_r', 'isr_neto_(mdp)_r', 'iva_neto_(mdp)_r',
#        'importaciones_neto_(mdp)_r', 'ing_no_trib_neto_(mdp)_r',
#        'ieps_hidrocarburos_neto_(mdp)_r',
#        'ieps_otros_petroliferos_neto_(mdp)_r', 'ieps_gasolina_neto_(mdp)_r',
#        'ieps_tabaco_neto_(mdp)_r', 'ieps_ba_neto_(mdp)_r',
#        'ieps_cerveza_neto_(mdp)_r', 'ieps_telecom_neto_(mdp)_r',
#        'ieps_otras_retenciones_neto_(mdp)_r', 'exportaciones_neto_(mdp)_r',
#        'isan_neto_(mdp)_r', 'accesorios_contribuciones_neto_(mdp)_r',
#        'otros_ingresos_tributarios_neto_(mdp)_r', 'ietu_neto_(mdp)_r',
#        'ide_neto_(mdp)_r', 'ieps_jys_neto_(mdp)_r', 'ieps_be_neto_(mdp)_r',
#        'ieps_bsaborizadas_neto_(mdp)_r', 'ieps_aadc_neto_(mdp)_r',
#        'ieps_plaguicidas_neto_(mdp)_r',
#        'ieps_combustibles_fosiles_neto_(mdp)_r',
#        'impuesto_extraccion_hidrocarburos_neto_(mdp)_r',
#        'ing_trib_sin_gasol_neto_(mdp)_r'],
#       dtype='object')

# %%
calendario_lif.columns
# Out:
# Index(['ingresos_del_sector_public_presupuestado',
#        'ingresos_gobierno_federal_presupuestado',
#        'ingresos_tributarios_presupuestado', 'isr_presupuestado',
#        'iva_presupuestado', 'ieps_presupuestado',
#        'importaciones_presupuestado', 'otros impuestos_presupuestado',
#        'derechos_presupuestado', 'aprovechamientos_presupuestado',
#        'transferencias_fmp_presupuestado',
#        'otros no tributarios_presupuestado',
#        'ingresos_no_tributatios_presupuestado', 'inpc',
#        'ingresos_del_sector_public_presupuestado_r',
#        'ingresos_gobierno_federal_presupuestado_r',
#        'ingresos_tributarios_presupuestado_r', 'isr_presupuestado_r',
#        'iva_presupuestado_r', 'ieps_presupuestado_r',
#        'importaciones_presupuestado_r', 'otros impuestos_presupuestado_r',
#        'derechos_presupuestado_r', 'aprovechamientos_presupuestado_r',
#        'transferencias_fmp_presupuestado_r',
#        'otros no tributarios_presupuestado_r',
#        'ingresos_no_tributatios_presupuestado_r'],
#       dtype='object')

# %%
accuracies_lif = []
dates = [('2016-01-01','2016-12-01'),
         ('2017-01-01','2017-12-01'),
         ('2018-01-01','2018-12-01'),
         ('2019-01-01','2019-12-01')]
variables = [('ing_trib_neto_(mdp)_r', 'ingresos_tributarios_presupuestado'),
              ('isr_neto_(mdp)_r', 'isr_presupuestado'),
              ('iva_neto_(mdp)_r', 'iva_presupuestado'),
              ('ieps_neto_(mdp)_r', 'ieps_presupuestado'),
              ('importaciones_neto_(mdp)_r', 'importaciones_presupuestado')]
for var in variables:
    for date in dates:
        accuracies = (mv.compute_accuracy_scores(ingresos_netos[var[0]],
                               calendario_lif.loc[date[0]:date[1],var[1]]))
        accuracies['date'] = date[0]
        accuracies['variable'] = var[0]
        accuracies_lif.append(accuracies)

# %%
accuracies_lif = pd.DataFrame(accuracies_lif)

# %%
accuracies_lif[['variable', 'date', 'mape', 'rmse']].groupby('variable').mean()\
    .to_excel('../results/precision_lif_promedio.xlsx')

# %%
calendario_lif_y = calendario_lif.resample('YS').sum()

# %%
ingresos_netos_y = ingresos_netos.resample('YS').sum()

# %%
accuracies_lif = []
dates_y = [('2016-01-01','2016-12-01'),
         ('2017-01-01','2017-12-01'),
         ('2018-01-01','2018-12-01'),
         ('2019-01-01','2019-12-01')]
variables = [('ing_trib_neto_(mdp)_r', 'ingresos_tributarios_presupuestado_r'),
              ('isr_neto_(mdp)_r', 'isr_presupuestado_r'),
              ('iva_neto_(mdp)_r', 'iva_presupuestado_r'),
              ('ieps_neto_(mdp)_r', 'ieps_presupuestado_r'),
              ('importaciones_neto_(mdp)_r', 'importaciones_presupuestado_r')]
for var in variables:
    for date in dates:
        accuracies = (mv.compute_accuracy_scores(ingresos_netos[var[0]],
                               calendario_lif.loc[date[0]:date[1],var[1]]))
        accuracies['date'] = date[0]
        accuracies['variable'] = var[0]
        accuracies_lif.append(accuracies)

# %%
observado_y_presup = pd.merge(calendario_lif_y, ingresos_netos_y, left_index=True, right_index=True)

# %%
observado_y_presup[['ing_trib_neto_(mdp)_r', 'ingresos_tributarios_presupuestado']]
# Out:
#             ing_trib_neto_(mdp)_r  ingresos_tributarios_presupuestado
# fecha
# 2016-01-01           3.114509e+06                           2407716.7
# 2017-01-01           3.083038e+06                           2739366.9
# 2018-01-01           3.157853e+06                           2957469.8
# 2019-01-01           1.694967e+06                           1989374.5

# %%
observado_y_presup[['isr_neto_(mdp)_r', 'isr_presupuestado_r']]
# Out:
#             isr_neto_(mdp)_r  isr_presupuestado_r
# fecha
# 2016-01-01      1.634997e+06         1.432962e+06
# 2017-01-01      1.674918e+06         1.543352e+06
# 2018-01-01      1.716680e+06         1.615072e+06
# 2019-01-01      9.275894e+05         1.066748e+06

# %%
observado_y_presup[['iva_neto_(mdp)_r', 'iva_presupuestado_r']]
# Out:
#             iva_neto_(mdp)_r  iva_presupuestado_r
# fecha
# 2016-01-01     885040.493140        850897.167762
# 2017-01-01     872636.296416        862762.801682
# 2018-01-01     951394.715401        903779.041566
# 2019-01-01     478246.085431        592944.900624

# %%
observado_y_presup[['importaciones_neto_(mdp)_r', 'importaciones_presupuestado_r']]
# Out:
#             importaciones_neto_(mdp)_r  importaciones_presupuestado_r
# fecha
# 2016-01-01                57949.111042                   41605.695236
# 2017-01-01                56578.343710                   49563.985294
# 2018-01-01                67465.715761                   48765.547026
# 2019-01-01                31980.585856                   38954.131985
